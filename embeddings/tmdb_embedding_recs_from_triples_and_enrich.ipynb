# %% [markdown]
# # TMDB Recommendations from KG Triples → Enrich (Algorithm A) → Append as Triples
#
# This notebook:
# 1) Loads `movie_kg_triples.tsv` (head, rel, tail).
# 2) Extracts movies and their ratings.
# 3) Picks the top-N best-rated films.
# 4) For each, queries **TMDB recommendations**, then **enriches** each recommendation using *Algorithm A* (details + credits).
# 5) Appends the enriched information **as triples** to the same TSV (after creating a timestamped backup).

# %%
import os, re, unicodedata, time, shutil
import pandas as pd
from pathlib import Path
from dotenv import load_dotenv
import requests
from datetime import datetime

# --- Config ---
TOP_N_SEEDS     = 100   # number of KG movies to seed
RECS_PER_SEED   = 10   # number of recommendations per seed to take
SLEEP_SEC       = 0.25 # API politeness
KG_PATH    = Path("../data/kg/triples/movie_kg_triples.tsv")
OUT_PATH   = KG_PATH  # gleiche Datei bleibt Ziel

# Backup-Verzeichnis erstellen, falls es nicht existiert
BACKUP_DIR = KG_PATH.parent / "backups"
BACKUP_DIR.mkdir(parents=True, exist_ok=True)

# Backup-Dateiname mit Zeitstempel
timestamp   = datetime.now().strftime("%Y%m%d_%H%M%S")
BACKUP_PATH = BACKUP_DIR / f"movie_kg_triples_backup_{timestamp}.tsv"

# Load API key
load_dotenv()
TMDB_API_TOKEN = os.getenv('TMDB_API_TOKEN')
assert TMDB_API_TOKEN, "Please set TMDB_API_TOKEN in your environment (.env)."

HEADERS = {
    "Authorization": "Bearer " + TMDB_API_TOKEN,
    "Content-Type": "application/json;charset=utf-8"
}

print("KG file:", KG_PATH)
print("Backup will be written to:", BACKUP_PATH)
# Out:
# KG file: ../data/kg/triples/movie_kg_triples.tsv
# Backup will be written to: ../data/kg/triples/backups/movie_kg_triples_backup_20250915_010217.tsv

# %% [markdown]
# ## Load triples & extract movies with ratings

# %%
import numpy as np

triples = pd.read_csv(KG_PATH, sep="\\t", header=None, names=["head","rel","tail"])
print("Triples loaded:", len(triples))

# Bereits vorhandene Filmknoten im KG (an rdf:type = schema:Movie erkennbar)
existing_movies = set(
    triples.loc[
        (triples["rel"] == "rdf:type") & (triples["tail"] == "schema:Movie"),
        "head"
    ].astype(str)
)

# Optional: alle vorhandenen Tripel zum Feingranular-Deduplizieren
existing_triples = set(map(tuple, triples.astype(str).values.tolist()))
print(f"{len(existing_movies)} movies already in KG, {len(existing_triples)} triples total.")

# Helper: parse numeric fields like 'avgVote_8.4', 'personalVote_5.0', 'published_1989', 'runtime116'
def extract_personal_review(s: str | None) -> float | None:
    """Erwartet Tail wie 'personalVote_5.0' (evtl. auch 5,0)."""
    if s is None or (isinstance(s, float) and pd.isna(s)):
        return None
    txt = str(s)
    # 1) Versuche exakte Token-Variante
    m = re.search(r"personalVote[_:\s]*([0-9]+(?:[.,][0-9]+)?)", txt, flags=re.I)
    if m:
        return float(m.group(1).replace(",", "."))
    # 2) Fallback: irgend eine Zahl nach 'personal...'
    m = re.search(r"personal\w*\D*([0-9]+(?:[.,][0-9]+)?)", txt, flags=re.I)
    if m:
        return float(m.group(1).replace(",", "."))
    return None

def extract_avg_vote(s: str | None) -> float | None:
    """Erwartet Tail wie 'avgVote_8.4' (evtl. auch 8,4)."""
    if s is None or (isinstance(s, float) and pd.isna(s)):
        return None
    txt = str(s)
    # 1) Versuche exakte Token-Variante
    m = re.search(r"avgVote[_:\s]*([0-9]+(?:[.,][0-9]+)?)", txt, flags=re.I)
    if m:
        return float(m.group(1).replace(",", "."))
    # 2) Fallback: irgend eine Zahl nach 'avg...'
    m = re.search(r"avg\w*\D*([0-9]+(?:[.,][0-9]+)?)", txt, flags=re.I)
    if m:
        return float(m.group(1).replace(",", "."))
    return None

def extract_year(s: str | None) -> int | None:
    if s is None or (isinstance(s, float) and pd.isna(s)):
        return None
    m = re.search(r"(19|20)\d{2}", str(s))
    return int(m.group(0)) if m else None

# Collect movies
movies = triples[(triples["rel"]=="rdf:type") & (triples["tail"]=="schema:Movie")]["head"].unique()

# Build a small movie table
name_map = triples[triples["rel"]=="schema:name"].set_index("head")["tail"].to_dict()
year_map = triples[triples["rel"]=="schema:datePublished"].set_index("head")["tail"].to_dict()
agg_map  = triples[triples["rel"]=="schema:aggregateRating"].set_index("head")["tail"].to_dict()
rev_map  = triples[triples["rel"]=="schema:review"].set_index("head")["tail"].to_dict()

rows = []
for mid in movies:
    title = name_map.get(mid)
    year  = extract_year(year_map.get(mid))
    personal = extract_personal_review(rev_map.get(mid))   # 0–5
    avg     = extract_avg_vote(agg_map.get(mid))           # 0–10
    rows.append({
        "movie_id": mid, "title": title, "year": year,
        "personal5": personal, "avg10": avg
    })

movie_df = pd.DataFrame(rows)
# personal (0–5) auf 0–10 hochskalieren
movie_df["personal10"] = movie_df["personal5"].apply(lambda x: x*2 if pd.notna(x) else np.nan)

# Endscore: nutze personal10 wenn da, sonst avg10, sonst 0
movie_df["score10"] = movie_df.apply(
    lambda r: r["personal10"] if pd.notna(r["personal10"])
    else (r["avg10"] if pd.notna(r["avg10"]) else 0.0),
    axis=1
)

# Sortierung: Score absteigend, Jahr absteigend
movie_df_sorted = movie_df.sort_values(by=["score10","year"], ascending=[False, False]).reset_index(drop=True)

print(movie_df[["title","personal5","avg10","year","score10"]].head(20))
print(movie_df[["personal5","avg10","score10"]].describe())
print("Anzahl personal vorhanden:", movie_df["personal5"].notna().sum())
print("Anzahl avg vorhanden:", movie_df["avg10"].notna().sum())
# Out:
# Triples loaded: 58616
# 695 movies already in KG, 41199 triples total.
#                                     title  personal5  avg10  year  score10
# 0                              Twin Peaks        5.0  8.400  1989     10.0
# 1                              The Matrix        5.0  8.232  1999     10.0
# 2                                   Alien        5.0  8.164  1979     10.0
# 3                          Alien: Romulus        4.5  7.179  2024      9.0
# 4                 AVP: Alien vs. Predator        1.5  5.938  2004      3.0
# 5             Predator: Killer of Killers        3.0  7.904  2025      6.0
# 6                                 Weapons        3.0  7.420  2025      6.0
# 7   The Hunger Games: Mockingjay – Part 2        3.0  6.897  2015      6.0
# 8                              BlackBerry        4.0  7.127  2023      8.0
# 9                             Challengers        3.0  6.956  2024      6.0
# 10                                   Okja        4.0  7.349  2017      8.0
# 11                               Dominion        4.0  8.400  2018      8.0
# 12                               Superman        3.5  7.500  2025      7.0
# 13  The Hunger Games: Mockingjay – Part 1        3.0  6.800  2014      6.0
# 14        The Hunger Games: Catching Fire        4.0  7.400  2013      8.0
# 15                              Ballerina        4.0  7.400  2025      8.0
# 16                       The Hunger Games        2.5  7.218  2012      5.0
# 17                         Soldier Monika        3.5  0.000  2024      7.0
# 18                       The Big Lebowski        4.5  7.840  1998      9.0
# 19                             Eraserhead        5.0  7.358  1977     10.0
#         personal5       avg10     score10
# count  292.000000  695.000000  695.000000
# mean     3.715753    6.992131    7.080406
# std      1.060713    0.917993    1.588897
# min      0.500000    0.000000    0.000000
# 25%      3.000000    6.500000    6.200000
# 50%      4.000000    7.100000    7.000000
# 75%      4.500000    7.612000    8.000000
# max      5.000000    8.566000   10.000000
# Anzahl personal vorhanden: 292
# Anzahl avg vorhanden: 695
# /var/folders/rt/g4r6gn7d0tj7xck34sb648br0000gn/T/ipykernel_7674/3840670702.py:3: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   triples = pd.read_csv(KG_PATH, sep="\\t", header=None, names=["head","rel","tail"])

# %% [markdown]
# ## TMDB search & enrich (Algorithm A helpers)

# %%
def normalize_title(title):
    if not title:
        return ""
    title = unicodedata.normalize("NFKC", title)
    substitutions = {
        "–": "-", "—": "-", "−": "-",
        "×": "x", "’": "'", "“": '"', "”": '"', "…": "...",
        "&": "and",
    }
    for orig, repl in substitutions.items():
        title = title.replace(orig, repl)
    title = re.sub(r"\\s+", " ", title).strip().lower()
    return title

def search_exact_match(results, search_title):
    norm_search = normalize_title(search_title)
    for r in results:
        tmdb_title = r.get("title") or r.get("name") or ""
        if normalize_title(tmdb_title) == norm_search:
            return r
    return None

def search_movie_or_tv(title, year=None):
    # Try movie
    movie_url = "https://api.themoviedb.org/3/search/movie"
    params = {"query": title}
    if year:
        params["year"] = year
    resp = requests.get(movie_url, headers=HEADERS, params=params)
    if resp.status_code == 200:
        results = resp.json().get("results", [])
        match = search_exact_match(results, title)
        if match:
            match["media_type"] = "movie"
            return match
        if results:
            results[0]["media_type"] = "movie"
            return results[0]

    # Try TV
    tv_url = "https://api.themoviedb.org/3/search/tv"
    params = {"query": title}
    if year:
        params["first_air_date_year"] = year
    resp = requests.get(tv_url, headers=HEADERS, params=params)
    if resp.status_code == 200:
        results = resp.json().get("results", [])
        match = search_exact_match(results, title)
        if match:
            match["media_type"] = "tv"
            return match
        if results:
            results[0]["media_type"] = "tv"
            return results[0]
    return None

def get_details(tmdb_id, media_type):
    url = f"https://api.themoviedb.org/3/{media_type}/{tmdb_id}"
    resp = requests.get(url, headers=HEADERS)
    return resp.json() if resp.status_code == 200 else None

def get_credits(tmdb_id, media_type):
    url = f"https://api.themoviedb.org/3/{media_type}/{tmdb_id}/credits"
    resp = requests.get(url, headers=HEADERS)
    return resp.json() if resp.status_code == 200 else None

def get_recommendations(tmdb_id, media_type, page=1):
    url = f"https://api.themoviedb.org/3/{media_type}/{tmdb_id}/recommendations"
    resp = requests.get(url, headers=HEADERS, params={"page": page})
    return resp.json().get("results", []) if resp.status_code == 200 else []

# %% [markdown]
# ## Select top-N seeds and fetch TMDB recommendations

# %%
seeds = movie_df_sorted.head(TOP_N_SEEDS).copy()
print(f"Using top {len(seeds)} seeds from KG (by personal/avg rating).")
seed_hits = []

for _, row in seeds.iterrows():
    title, year = row["title"], row["year"]
    sr = search_movie_or_tv(title, year)
    if not sr:
        print(f"Seed not found on TMDB: {title} ({year})")
        continue
    seed_hits.append({"kg_movie_id": row["movie_id"], "title": title, "year": year, "tmdb_id": sr["id"], "media_type": sr["media_type"]})
    time.sleep(SLEEP_SEC)

print("Seeds matched on TMDB:", len(seed_hits))
seed_hits[:5]
# Out:
# Using top 100 seeds from KG (by personal/avg rating).
# Seeds matched on TMDB: 100
# [{'kg_movie_id': 'movie940721',
#   'title': 'Godzilla Minus One',
#   'year': 2023,
#   'tmdb_id': 940721,
#   'media_type': 'movie'},
#  {'kg_movie_id': 'movie872585',
#   'title': 'Oppenheimer',
#   'year': 2023,
#   'tmdb_id': 872585,
#   'media_type': 'movie'},
#  {'kg_movie_id': 'movie346698',
#   'title': 'Barbie',
#   'year': 2023,
#   'tmdb_id': 346698,
#   'media_type': 'movie'},
#  {'kg_movie_id': 'movie961323',
#   'title': 'Nimona',
#   'year': 2023,
#   'tmdb_id': 961323,
#   'media_type': 'movie'},
#  {'kg_movie_id': 'movie603692',
#   'title': 'John Wick: Chapter 4',
#   'year': 2023,
#   'tmdb_id': 603692,
#   'media_type': 'movie'}]

# %% [markdown]
# ## Enrich recommendations (Algorithm A style)

# %%
tmdb_media_base_url = "https://www.themoviedb.org/"
tmdb_poster_base_url = "https://image.tmdb.org/t/p/"
tmdb_person_base_url = "https://www.themoviedb.org/person/"
tmdb_genre_base_url = "https://www.themoviedb.org/genre/"
tmdb_company_base_url = "https://www.themoviedb.org/company/"
size = "original"

recs_enriched = []

for sh in seed_hits:
    sid, mtype = sh["tmdb_id"], sh["media_type"]
    recs = get_recommendations(sid, mtype, page=1)[:RECS_PER_SEED]
    for rec in recs:
        rec_id = rec["id"]
        rec_type = rec.get("media_type") or mtype  # assume same type if missing
        det = get_details(rec_id, rec_type)
        cred = get_credits(rec_id, rec_type)
        if not det:
            continue

        # collect enriched fields like Algorithm A
        title = det.get("title") or det.get("name")
        year  = None
        date_str = det.get("release_date") or det.get("first_air_date")
        if date_str and len(date_str)>=4:
            try: year = int(date_str[:4])
            except: year = None

        genres = [f"{g.get('name')}:{tmdb_genre_base_url}{g.get('id')}" for g in det.get("genres", [])]
        production_companies = [f"{p.get('name')}:{tmdb_company_base_url}{p.get('id')}:{p.get('origin_country')}" for p in det.get("production_companies", [])]
        production_countries = [f"{p.get('name')}:{p.get('iso_3166_1')}" for p in det.get("production_countries", [])]
        spoken_languages = [f"{s.get('english_name')}:{s.get('iso_639_1')}" for s in det.get("spoken_languages", [])]

        directors = []
        actors = []
        if cred:
            crew = cred.get("crew", [])
            directors = [f"{p.get('name')}:{tmdb_person_base_url}{p.get('id')}" for p in crew if p.get("job")=="Director"]
            cast = cred.get("cast", [])[:10]
            actors = [f"{a.get('name')}:{tmdb_person_base_url}{a.get('id')}" for a in cast]

        poster_url = None
        pp = det.get("poster_path")
        if pp: poster_url = tmdb_poster_base_url + size + pp

        recs_enriched.append({
            "seed_tmdb_id": sid,
            "seed_media_type": mtype,
            "tmdb_id": rec_id,
            "media_type": rec_type,
            "title": title,
            "year": year,
            "overview": det.get("overview"),
            "genres": genres or None,
            "runtime": det.get("runtime") if rec_type=="movie" else None,
            "vote_average": det.get("vote_average"),
            "poster_url": poster_url,
            "origin_country": det.get("origin_country"),
            "original_language": det.get("original_language"),
            "popularity": det.get("popularity"),
            "production_companies": production_companies or None,
            "production_countries": production_countries or None,
            "spoken_languages": spoken_languages or None,
            "directors": directors or None,
            "actors": actors or None,
            "tmdb_url": tmdb_media_base_url + f"{rec_type}/" + str(rec_id),
        })
        time.sleep(SLEEP_SEC)

print("Total recommendations enriched:", len(recs_enriched))
len(recs_enriched)
# Out:
# Total recommendations enriched: 1000
# [{'seed_tmdb_id': 940721,
#   'seed_media_type': 'movie',
#   'tmdb_id': 315011,
#   'media_type': 'movie',
#   'title': 'Shin Godzilla',
#   'year': 2016,
#   'overview': "When a massive, gilled monster emerges from the deep and tears through the city, the government scrambles to save its citizens.  A rag-tag team of volunteers cuts through a web of red tape to uncover the monster's weakness and its mysterious ties to a foreign superpower.  But time is not on their side - the greatest catastrophe to ever befall the world is about to evolve right before their very eyes.",
#   'genres': ['Action:https://www.themoviedb.org/genre/28',
#    'Science Fiction:https://www.themoviedb.org/genre/878',
#    'Horror:https://www.themoviedb.org/genre/27'],
#   'runtime': 120,
#   'vote_average': 7.2,
#   'poster_url': 'https://image.tmdb.org/t/p/original/jPNShaWZMpVF0iQ7j1dvTuZLD20.jpg',
#   'origin_country': ['JP'],
#   'original_language': 'ja',
#   'popularity': 8.4151,
#   'production_companies': ['Toho Pictures:https://www.themoviedb.org/company/49301:JP',
#    'Cine Bazar:https://www.themoviedb.org/company/5896:JP'],
#   'production_countries': ['Japan:JP'],
#   'spoken_languages': ['Italian:it', 'German:de', 'English:en', 'Japanese:ja'],
#   'directors': ['Shinji Higuchi:https://www.themoviedb.org/person/80752',
#    'Hideaki Anno:https://www.themoviedb.org/person/77921'],
#   'actors': ['Hiroki Hasegawa:https://www.themoviedb.org/person/1098600',
#    'Yutaka Takenouchi:https://www.themoviedb.org/person/588403',
#    'Satomi Ishihara:https://www.themoviedb.org/person/224664',
#    'Kengo Kora:https://www.themoviedb.org/person/120690',
#    'Satoru Matsuo:https://www.themoviedb.org/person/1502395',
#    'Mikako Ichikawa:https://www.themoviedb.org/person/130654',
#    'Issey Takahashi:https://www.themoviedb.org/person/87662',
#    'Kanji Tsuda:https://www.themoviedb.org/person/13256',
#    'Shinya Tsukamoto:https://www.themoviedb.org/person/58608',
#    'Toru Nomaguchi:https://www.themoviedb.org/person/1405926'],
#   'tmdb_url': 'https://www.themoviedb.org/movie/315011'},
#  {'seed_tmdb_id': 940721,
#   'seed_media_type': 'movie',
#   'tmdb_id': 823464,
#   'media_type': 'movie',
#   'title': 'Godzilla x Kong: The New Empire',
#   'year': 2024,
#   'overview': 'Following their explosive showdown, Godzilla and Kong must reunite against a colossal undiscovered threat hidden within our world, challenging their very existence – and our own.',
#   'genres': ['Action:https://www.themoviedb.org/genre/28',
#    'Adventure:https://www.themoviedb.org/genre/12',
#    'Science Fiction:https://www.themoviedb.org/genre/878'],
#   'runtime': 115,
#   'vote_average': 7.1,
#   'poster_url': 'https://image.tmdb.org/t/p/original/z1p34vh7dEOnLDmyCrlUVLuoDzd.jpg',
#   'origin_country': ['US'],
#   'original_language': 'en',
#   'popularity':
jpg',
#   'origin_country': ['US'],
#   'original_language': 'en',
#   'popularity': 10.9473,
#   'production_companies': ['Jerry Bruckheimer Films:https://www.themoviedb.org/company/130:US',
#    'Black Bear Pictures:https://www.themoviedb.org/company/22146:US',
#    'Toff Guy Films:https://www.themoviedb.org/company/2900:GB'],
#   'production_countries': ['United Kingdom:GB', 'United States of America:US'],
#   'spoken_languages': ['English:en', 'German:de'],
#   'directors': ['Guy Ritchie:https://www.themoviedb.org/person/956'],
#   'actors': ['Henry Cavill:https://www.themoviedb.org/person/73968',
#    'Eiza González:https://www.themoviedb.org/person/1222992',
#    'Alan Ritchson:https://www.themoviedb.org/person/64295',
#    'Henry Golding:https://www.themoviedb.org/person/1807132',
#    'Cary Elwes:https://www.themoviedb.org/person/2130',
#    'Alex Pettyfer:https://www.themoviedb.org/person/61363',
#    'Hero Fiennes Tiffin:https://www.themoviedb.org/person/1114487',
#    'Babs Olusanmokun:https://www.themoviedb.org/person/205923',
#    'Henry Zaga:https://www.themoviedb.org/person/1563169',
#    'Til Schweiger:https://www.themoviedb.org/person/1844'],
#   'tmdb_url': 'https://www.themoviedb.org/movie/799583'},
#  {'seed_tmdb_id': 940721,
#   'seed_media_type': 'movie',
#   'tmdb_id': 816741,
#   'media_type': 'movie',
#   'title': 'Grey Eyes',
#   'year': 2018,
#   'overview': "In a post-apocalyptic future, mankind is color blind. A brilliant scientist suddenly dies, leaving his precious briefcase-filled with a highly-addictive synthetic drug that allows people to see colors again-to Ana, a mere 12-year-old girl. Possession of the briefcase makes her the target of a doctor with wicked plans for the drug, and her only hope to escape his pursuit relies on the aid of the dead scientist's two devoted bodyguards. Together, their epic, perilous journey pivots on a tremendous secret: Ana herself could be the key to salvaging a world in ruins.",
#   'genres': ['Action:https://www.themoviedb.org/genre/28',
#    'Science Fiction:https://www.themoviedb.org/genre/878'],
#   'runtime': 100,
#   'vote_average': 5.8,
#   'poster_url': 'https://image.tmdb.org/t/p/original/5InVYa7CcbGioPvQ6ig4Lz4iLlR.jpg',
#   'origin_country': ['ES'],
#   'original_language': 'es',
#   'popularity': 2.7275,
#   'production_companies': ['Fundación Dodecá:https://www.themoviedb.org/company/159296:'],
#   'production_countries': ['Uruguay:UY'],
#   'spoken_languages': ['Spanish:es'],
#   'directors': ['Santiago Ventura:https://www.themoviedb.org/person/1494770'],
#   'actors': ['William Prociuk:https://www.themoviedb.org/person/1348750',
#    'Fernando Amaral:https://www.themoviedb.org/person/3451017',
#    'Cecilia Milano:https://www.themoviedb.org/person/3023434',
#    'Christian Zagia:https://www.themoviedb.org/person/1669337',
#    'Rafael Soliwoda:https://www.themoviedb.org/person/1050051',
#    'Fiorella Bottaioli:https://www.themoviedb.org/person/3263520'],
#   'tmdb_url': 'https://www.themoviedb.org/movie/816741'},
#  {'seed_tmdb_id': 940721,
#   'seed_media_type': 'movie',
#   'tmdb_id': 843527,
#   'media_type': 'movie',
#   'title': 'The Idea of You',
#   'year': 2024,
#   'overview': "40-year-old single mom Solène begins an unexpected romance with 24-year-old Hayes Campbell, the lead singer of August Moon, the hottest boy band on the planet. As they begin a whirlwind romance, it isn't long before Hayes' superstar status poses unavoidable challenges to their relationship, and Solène soon discovers that life in the glare of his spotlight might be more than she bargained for.",
#   'genres': ['Romance:https://www.themoviedb.org/genre/10749',
#    'Drama:https://www.themoviedb.org/genre/18',
#    'Comedy:https://www.themoviedb.org/genre/35'],
#   'runtime': 116,
#   'vote_average': 7.4,
#   'poster_url': 'https://image.tmdb.org/t/p/original/Y5P4Q3q8nrruZ9aD3wXeJS2Plg.jpg',
#   'origin_country': ['US'],
#   'original_language': 'en',
#   'popularity':
},
#  {'seed_tmdb_id': 872585,
#   'seed_media_type': 'movie',
#   'tmdb_id': 937746,
#   'media_type': 'movie',
#   'title': 'Io Capitano',
#   'year': 2023,
#   'overview': 'Longing for a brighter future, two Senegalese teenagers embark on a journey from West Africa to Italy. However, between their dreams and reality lies a labyrinth of checkpoints, the Sahara Desert, and the vast waters of the Mediterranean.',
#   'genres': ['Adventure:https://www.themoviedb.org/genre/12',
#    'Drama:https://www.themoviedb.org/genre/18'],
#   'runtime': 121,
#   'vote_average': 7.8,
#   'poster_url': 'https://image.tmdb.org/t/p/original/kGlZFwUQI5gAUdySNFfqGIkAF9n.jpg',
#   'origin_country': ['IT'],
#   'original_language': 'it',
#   'popularity': 2.8664,
#   'production_companies': ['Archimede:https://www.themoviedb.org/company/53334:IT',
#    'RAI Cinema:https://www.themoviedb.org/company/155990:IT',
#    'Tarantula:https://www.themoviedb.org/company/8471:BE',
#    'Pathé:https://www.themoviedb.org/company/7981:FR',
#    'Logical Content Ventures:https://www.themoviedb.org/company/209127:FR'],
#   'production_countries': ['Belgium:BE', 'France:FR', 'Italy:IT'],
#   'spoken_languages': ['English:en', 'French:fr', 'Italian:it', 'Wolof:wo'],
#   'directors': ['Matteo Garrone:https://www.themoviedb.org/person/63973'],
#   'actors': ['Seydou Sarr:https://www.themoviedb.org/person/3626193',
#    'Moustapha Fall:https://www.themoviedb.org/person/3626194',
#    'Issaka Sawadogo:https://www.themoviedb.org/person/23301',
#    'Hichem Yacoubi:https://www.themoviedb.org/person/89625',
#    'Doodou Sagna:https://www.themoviedb.org/person/4264688',
#    'Khady Sy:https://www.themoviedb.org/person/4264689',
#    'Venus Gueye:https://www.themoviedb.org/person/4264691',
#    'Cheick Oumar Diaw:https://www.themoviedb.org/person/4264692',
#    'Joe Lassana:https://www.themoviedb.org/person/4439793',
#    'Mamadou Sani:https://www.themoviedb.org/person/4439797'],
#   'tmdb_url': 'https://www.themoviedb.org/movie/937746'},
#  {'seed_tmdb_id': 872585,
#   'seed_media_type': 'movie',
#   'tmdb_id': 945729,
#   'media_type': 'movie',
#   'title': 'A Haunting in Venice',
#   'year': 2023,
#   'overview': 'Celebrated sleuth Hercule Poirot, now retired and living in self-imposed exile in Venice, reluctantly attends a Halloween séance at a decaying, haunted palazzo. When one of the guests is murdered, the detective is thrust into a sinister world of shadows and secrets.',
#   'genres': ['Mystery:https://www.themoviedb.org/genre/9648',
#    'Thriller:https://www.themoviedb.org/genre/53',
#    'Crime:https://www.themoviedb.org/genre/80'],
#   'runtime': 104,
#   'vote_average': 6.588,
#   'poster_url': 'https://image.tmdb.org/t/p/original/l6iwxT0NbVw6QiF08YTIuTnXS82.jpg',
#   'origin_country': ['GB', 'US'],
#   'original_language': 'en',
#   'popularity': 6.8661,
#   'production_companies': ['20th Century Studios:https://www.themoviedb.org/company/127928:US',
#    'Scott Free Productions:https://www.themoviedb.org/company/1645:GB',
#    'The Mark Gordon Company:https://www.themoviedb.org/company/1557:US',
#    'Genre Films:https://www.themoviedb.org/company/28788:US',
#    'Agatha Christie Limited:https://www.themoviedb.org/company/84097:GB'],
#   'production_countries': ['United Kingdom:GB', 'United States of America:US'],
#   'spoken_languages': ['English:en',
#    'French:fr',
#    'Italian:it',
#    'Latin:la',
#    'Spanish:es'],
#   'directors': ['Kenneth Branagh:https://www.themoviedb.org/person/11181'],
#    'Robert Downey Jr.:https://www.themoviedb.org/person/3223',
#    'Florence Pugh:https://www.themoviedb.org/person/1373737',
#    'Josh Hartnett:https://www.themoviedb.org/person/2299',
#    'Casey Affleck:https://www.themoviedb.org/person/1893',
#    'Rami Malek:https://www.themoviedb.org/person/17838',
#    'Kenneth Branagh:https://www.themoviedb.org/person/11181',
#    'Benny Safdie:https://www.themoviedb.org/person/227564'],
#   'tmdb_url': 'https://www.themoviedb.org/movie/872585'},
#  {'seed_tmdb_id': 346698,
#   'seed_media_type': 'movie',
#   'tmdb_id': 976573,
#   'media_type': 'movie',
#   'title': 'Elemental',
#   'year': 2023,
#   'overview': 'In a city where fire, water, land and air residents live together, a fiery young woman and a go-with-the-flow guy will discover something elemental: how much they have in common.',
#   'genres': ['Animation:https://www.themoviedb.org/genre/16',
#    'Comedy:https://www.themoviedb.org/genre/35',
#    'Family:https://www.themoviedb.org/genre/10751',
#    'Fantasy:https://www.themoviedb.org/genre/14',
#    'Romance:https://www.themoviedb.org/genre/10749'],
#   'runtime': 102,
#   'vote_average': 7.6,
#   'poster_url': 'https://image.tmdb.org/t/p/original/4Y1WNkd88JXmGfhtWR7dmDAo1T2.jpg',
#   'origin_country': ['US'],
#   'original_language': 'en',
#   'popularity': 12.3727,
#   'production_companies': ['Pixar:https://www.themoviedb.org/company/3:US'],
#   'production_countries': ['United States of America:US'],
#   'spoken_languages': ['English:en'],
#   'directors': ['Peter Sohn:https://www.themoviedb.org/person/21198'],
#   'actors': ['Leah Lewis:https://www.themoviedb.org/person/1087262',
#    'Mamoudou Athie:https://www.themoviedb.org/person/1639848',
#    'Ronnie del Carmen:https://www.themoviedb.org/person/1236458',
#    'Shila Ommi:https://www.themoviedb.org/person/2073564',
#    'Wendi McLendon-Covey:https://www.themoviedb.org/person/63234',
#    "Catherine O'Hara:https://www.themoviedb.org/person/11514",
#    'Mason Wertheimer:https://www.themoviedb.org/person/3983226',
#    'Ronobir Lahiri:https://www.themoviedb.org/person/1217619',
#    'Wilma Bonet:https://www.themoviedb.org/person/1576334',
#    'Joe Pera:https://www.themoviedb.org/person/1663974'],
#   'tmdb_url': 'https://www.themoviedb.org/movie/976573'},
#  {'seed_tmdb_id': 346698,
#   'seed_media_type': 'movie',
#   'tmdb_id': 298618,
#   'media_type': 'movie',
#   'title': 'The Flash',
#   'year': 2023,
#   'overview': "When his attempt to save his family inadvertently alters the future, Barry Allen becomes trapped in a reality in which General Zod has returned and there are no Super Heroes to turn to. In order to save the world that he is in and return to the future that he knows, Barry's only hope is to race for his life. But will making the ultimate sacrifice be enough to reset the universe?",
#   'genres': ['Adventure:https://www.themoviedb.org/genre/12',
#    'Action:https://www.themoviedb.org/genre/28',
#    'Science Fiction:https://www.themoviedb.org/genre/878'],
#   'runtime': 144,
#   'vote_average': 6.6,
#   'poster_url': 'https://image.tmdb.org/t/p/original/rktDFPbfHfUbArZ6OOOKsXcv0Bm.jpg',
#   'origin_country': ['US'],
#   'original_language': 'en',
#   'popularity': 11.3613,
#   'production_companies': ['Warner Bros. Pictures:https://www.themoviedb.org/company/174:US',
#    'Double Dream:https://www.themoviedb.org/company/152809:US',
#    'The Disco Factory:https://www.themoviedb.org/company/170335:US',
#    'DC Films:https://www.themoviedb.org/company/128064:US'],
#   'production_countries': ['United States of America:US'],
#   'spoken_languages': ['English:en', 'Spanish:es', 'Russian:ru'],
#   'directors': ['Andy Muschietti:https://www.themoviedb.org/person/1113116'],
#   'actors': ['Ezra Miller:https://www.themoviedb.org/person/132157',
#    'Sasha Calle:https://www.themoviedb.org/person/2542319',
#    'Michael Keaton:https://www.themoviedb.org/person/2232',
#    'Michael Shannon:https://www.themoviedb.org/person/335',
#    'Ron Livingston:https://www.themoviedb.org/person/17402',
#    'Maribel Verdú:https://www.themoviedb.org/person/16971',
#    'Kiersey Clemons:https://www.themoviedb.org/person/1253355',
#    'Antje Traue:https://www.themoviedb.org/person/43202',
#    'Saoirse-Monica Jackson:https://www.themoviedb.org/person/1660888',
#    'Rudy Mancuso:https://www.themoviedb.org/person/1727045'],
#   'tmdb_url': 'https://www.themoviedb.org/movie/298618'},
#  {'seed_tmdb_id': 346698,
#   'seed_media_type': 'movie',
#   'tmdb_id': 615656,
#   'media_type': 'movie',
#   'title': 'Meg 2: The Trench',
#   'year': 2023,
#   'overview': 'An exploratory dive into the deepest depths of the ocean of a daring research team spirals into chaos when a malevolent mining operation threatens their mission and forces them into a high-stakes battle for survival.',
#   'genres': ['Action:https://www.themoviedb.org/genre/28',
#    'Science Fiction:https://www.themoviedb.org/genre/878',
#    'Horror:https://www.themoviedb.org/genre/27'],
#   'runtime': 116,
#   'vote_average': 6.416,
#   'poster_url': 'https://image.tmdb.org/t/p/original/4m1Au3YkjqsxF8iwQy0fPYSxE0h.jpg',
#   'origin_country': ['US'],
#   'original_language': 'en',
#   'popularity': 11.9192,
#   'production_companies': ['Apelles Entertainment:https://www.themoviedb.org/company/56242:US',
#    'Warner Bros. Pictures:https://www.themoviedb.org/company/174:US',
#    'di Bonaventura Pictures:https://www.themoviedb.org/company/435:US',
#    'CMC Pictures:https://www.themoviedb.org/company/92484:CN',
#    'Onaroll Productions:https://www.themoviedb.org/company/208094:',
#    'DF Pictures:https://www.themoviedb.org/company/65442:CN'],
#   'production_countries': ['China:CN', 'United States of America:US'],
#   'spoken_languages': ['English:en'],
#   'directors': ['Ben Wheatley:https://www.themoviedb.org/person/137467'],
#   'actors': ['Jason Statham:https://www.themoviedb.org/person/976',
#    'Wu Jing:https://www.themoviedb.org/person/78871',
#    'Shuya Sophia Cai:https://www.themoviedb.org/person/1704579',
#    'Page Kennedy:https://www.themoviedb.org/person/177214',
#    'Sergio Peris-Mencheta:https://www.themoviedb.org/person/78994',
#    'Sienna Guillory:https://www.themoviedb.org/person/7055',
#    'Cliff Curtis:https://www.themoviedb.org/person/7248',
#    'Skyler Samuels:https://www.themoviedb.org/person/110930',
#    'Melissanthi Mahut:https://www.themoviedb.org/person/1977759',
#    'Whoopie van Raam:https://www.themoviedb.org/person/1503556'],
#   'tmdb_url': 'https://www.themoviedb.org/movie/615656'},
#  {'seed_tmdb_id': 346698,
#   'seed_media_type': 'movie',
#   'tmdb_id': 335977,
#   'media_type': 'movie',
#   'title': 'Indiana Jones and the Dial of Destiny',
#   'year': 2023,
#   'overview': "Finding himself in a new era, and approaching retirement, Indy wrestles with fitting into a world that seems to have outgrown him. But as the tentacles of an all-too-familiar evil return in the form of an old rival, Indy must don his hat and pick up his whip once more to make sure an ancient and powerful artifact doesn't fall into the wrong hands.",
#   'genres': ['Adventure:https://www.themoviedb.org/genre/12',
#    'Action:https://www.themoviedb.org/genre/28'],
#   'runtime': 155,
#   'vote_average': 6.541,
#   'poster_url': 'https://image.tmdb.org/t/p/original/Af4bXE63pVsb2FtbW8uYIyPBadD.jpg',
#   'origin_country': ['US'],
#   'original_language': 'en',
#   'popularity': 8.4845,
#   'production_companies': ['Lucasfilm Ltd.:https://www.themoviedb.org/company/1:US'],
#   'production_countries': ['United States of America:US'],
#   'spoken_languages': ['English:
US'],
#   'production_countries': ['United States of America:US'],
#   'spoken_languages': ['English:en'],
#   'directors': ['Rich Moore:https://www.themoviedb.org/person/165787'],
#   'actors': ['John C. Reilly:https://www.themoviedb.org/person/4764',
#    'Sarah Silverman:https://www.themoviedb.org/person/7404',
#    'Jack McBrayer:https://www.themoviedb.org/person/58737',
#    'Alan Tudyk:https://www.themoviedb.org/person/21088',
#    'Jane Lynch:https://www.themoviedb.org/person/43775',
#    'Rich Moore:https://www.themoviedb.org/person/165787',
#    'Raymond S. Persi:https://www.themoviedb.org/person/1223658',
#    'Mindy Kaling:https://www.themoviedb.org/person/125167',
#    'Jamie Elman:https://www.themoviedb.org/person/95002',
#    'Adam Carolla:https://www.themoviedb.org/person/76245'],
#   'tmdb_url': 'https://www.themoviedb.org/movie/82690'},
#  {'seed_tmdb_id': 122,
#   'seed_media_type': 'movie',
#   'tmdb_id': 671,
#   'media_type': 'movie',
#   'title': "Harry Potter and the Philosopher's Stone",
#   'year': 2001,
#   'overview': "Harry Potter has lived under the stairs at his aunt and uncle's house his whole life. But on his 11th birthday, he learns he's a powerful wizard—with a place waiting for him at the Hogwarts School of Witchcraft and Wizardry. As he learns to harness his newfound powers with the help of the school's kindly headmaster, Harry uncovers the truth about his parents' deaths—and about the villain who's to blame.",
#   'genres': ['Adventure:https://www.themoviedb.org/genre/12',
#    'Fantasy:https://www.themoviedb.org/genre/14'],
#   'runtime': 152,
#   'vote_average': 7.901,
#   'poster_url': 'https://image.tmdb.org/t/p/original/wuMc08IPKEatf9rnMNXvIDxqP4W.jpg',
#   'origin_country': ['GB'],
#   'original_language': 'en',
#   'popularity': 35.245,
#   'production_companies': ['Warner Bros. Pictures:https://www.themoviedb.org/company/174:US',
#    'Heyday Films:https://www.themoviedb.org/company/437:GB',
#    '1492 Pictures:https://www.themoviedb.org/company/436:US'],
#   'production_countries': ['United Kingdom:GB', 'United States of America:US'],
#   'spoken_languages': ['English:en'],
#   'directors': ['Chris Columbus:https://www.themoviedb.org/person/10965'],
#   'actors': ['Daniel Radcliffe:https://www.themoviedb.org/person/10980',
#    'Rupert Grint:https://www.themoviedb.org/person/10989',
#    'Emma Watson:https://www.themoviedb.org/person/10990',
#    'Richard Harris:https://www.themoviedb.org/person/194',
#    'Tom Felton:https://www.themoviedb.org/person/10993',
#    'Alan Rickman:https://www.themoviedb.org/person/4566',
#    'Robbie Coltrane:https://www.themoviedb.org/person/1923',
#    'Maggie Smith:https://www.themoviedb.org/person/10978',
#    'Richard Griffiths:https://www.themoviedb.org/person/10983',
#    'Ian Hart:https://www.themoviedb.org/person/10985'],
#   'tmdb_url': 'https://www.themoviedb.org/movie/671'},
#  {'seed_tmdb_id': 122,
#   'seed_media_type': 'movie',
#   'tmdb_id': 36657,
#   'media_type': 'movie',
#   'title': 'X-Men',
#   'year': 2000,
#   'overview': 'Two mutants, Rogue and Wolverine, come to a private academy for their kind whose resident superhero team, the X-Men, must oppose a terrorist organization with similar powers.',
#   'genres': ['Adventure:https://www.themoviedb.org/genre/12',
#    'Action:https://www.themoviedb.org/genre/28',
#    'Science Fiction:https://www.themoviedb.org/genre/878'],
#   'runtime': 104,
#   'vote_average': 7.006,
#   'poster_url': 'https://image.tmdb.org/t/p/original/bRDAc4GogyS9ci3ow7UnInOcriN.jpg',
#   'origin_country': ['US'],
#   'original_language': 'en',
#   'popularity': 0.6033,
#   'production_companies': ["The Donners' Company:https://www.themoviedb.org/company/431:US",
#    'Bad Hat Harry Productions:https://www.themoviedb.org/company/9168:US',
#    '20th Century Fox:https://www.themoviedb.org/company/25:US',
#    'Marvel Entertainment Group:https://www.themoviedb.org/company/160251:US'],
#   'production_countries': ['United States of America:US'],
#   'spoken_languages': ['English:en'],
#   'directors': ['Bryan Singer:https://www.themoviedb.org/person/9032'],
#   'actors': ['Hugh Jackman:https://www.themoviedb.org/person/6968',
#    'Patrick Stewart:https://www.themoviedb.org/person/2387',
#    'Ian McKellen:https://www.themoviedb.org/person/1327',
#    'Famke Janssen:https://www.themoviedb.org/person/10696',
#    'James Marsden:https://www.themoviedb.org/person/11006',
#    'Halle Berry:https://www.themoviedb.org/person/4587',
#    'Anna Paquin:https://www.themoviedb.org/person/10690',
#    'Tyler Mane:https://www.themoviedb.org/person/9832',
#    'Ray Park:https://www.themoviedb.org/person/11007',
#    'Rebecca Romijn:https://www.themoviedb.org/person/11008'],
#   'tmdb_url': 'https://www.themoviedb.org/movie/36657'}]

# %% [markdown]
# ## Convert enriched recommendations to triples

# %%
# Build triples for each recommendation
new_triples = []
seen_new_triples = set()  # zum Deduplizieren innerhalb dieser Session

def movie_node(tmdb_id): return f"movie{tmdb_id}"
def person_node(pid):    return f"person{pid}"

def add_triple(h, r, t):
    key = (str(h), str(r), str(t))
    # vermeide Duplikate: nicht erneut hinzufügen, wenn schon im KG ODER schon in dieser Session erzeugt
    if key in existing_triples or key in seen_new_triples:
        return
    seen_new_triples.add(key)
    new_triples.append([h, r, t])

for r in recs_enriched:
    mid = movie_node(r["tmdb_id"])

    # **WICHTIG**: Falls der Film bereits als Knoten (rdf:type Movie) existiert -> komplett überspringen
    if mid in existing_movies:
        continue

    # Film-Basis
    new_triples.append([mid, "rdf:type", "schema:Movie"])
    if r["title"]:
        new_triples.append([mid, "schema:name", r["title"]])
    if r["year"]:
        new_triples.append([mid, "schema:datePublished", f"published_{r['year']}"])
    if r["vote_average"] is not None:
        new_triples.append([mid, "schema:aggregateRating", f"avgVote_{r['vote_average']}"])
    if r["runtime"]:
        try:
            new_triples.append([mid, "schema:duration", f"runtime{int(r['runtime'])}"])
        except Exception:
            pass
    if r["popularity"] is not None:
        new_triples.append([mid, "ex:popularity", f"popul_{r['popularity']}"])
    if r["original_language"]:
        new_triples.append([mid, "ex:originalLanguage", str(r["original_language"])])
    if r["origin_country"]:
        oc = r["origin_country"]
        if isinstance(oc, list):
            for c in oc:
                new_triples.append([mid, "ex:originCountry", str(c)])
        else:
            new_triples.append([mid, "ex:originCountry", str(oc)])

    # Directors
    if r["directors"]:
        for d in r["directors"]:
            name, _, _ = d.partition(":http")
            pid_match = re.search(r"/person/(\d+)", d)
            pid = pid_match.group(1) if pid_match else normalize_title(name).replace(" ","_")
            pnode = person_node(pid)
            new_triples.append([mid, "schema:director", pnode])
            new_triples.append([pnode, "rdf:type", "schema:Person"])
            new_triples.append([pnode, "schema:name", name.strip()])

    # Actors
    if r["actors"]:
        for a in r["actors"]:
            name, _, _ = a.partition(":http")
            pid_match = re.search(r"/person/(\d+)", a)
            pid = pid_match.group(1) if pid_match else normalize_title(name).replace(" ","_")
            pnode = person_node(pid)
            new_triples.append([mid, "schema:actor", pnode])
            new_triples.append([pnode, "rdf:type", "schema:Person"])
            new_triples.append([pnode, "schema:name", name.strip()])

    # Link back: recommended from which seed (optional edge)
    new_triples.append([mid, "ex:recommendedFrom", movie_node(str(r["seed_tmdb_id"]))])

print("New triples to append:", len(new_triples))
len(new_triples)
new_triples
# Out:
# New triples to append: 28638
# [['movie437342', 'rdf:type', 'schema:Movie'],
#  ['movie437342', 'schema:name', 'The First Omen'],
#  ['movie437342', 'schema:datePublished', 'published_2024'],
#  ['movie437342', 'schema:aggregateRating', 'avgVote_6.9'],
#  ['movie437342', 'schema:duration', 'runtime119'],
#  ['movie437342', 'ex:popularity', 'popul_7.9004'],
#  ['movie437342', 'ex:originalLanguage', 'en'],
#  ['movie437342', 'ex:originCountry', 'US'],
#  ['movie437342', 'schema:director', 'person1706480'],
#  ['person1706480', 'rdf:type', 'schema:Person'],
#  ['person1706480', 'schema:name', 'Arkasha Stevenson'],
#  ['movie437342', 'schema:actor', 'person1472584'],
#  ['person1472584', 'rdf:type', 'schema:Person'],
#  ['person1472584', 'schema:name', 'Nell Tiger Free'],
#  ['movie437342', 'schema:actor', 'person202032'],
#  ['person202032', 'rdf:type', 'schema:Person'],
#  ['person202032', 'schema:name', 'Ralph Ineson'],
#  ['movie437342', 'schema:actor', 'person27396'],
#  ['person27396', 'rdf:type', 'schema:Person'],
#  ['person27396', 'schema:name', 'Sônia Braga'],
#  ['movie437342', 'schema:actor', 'person1260004'],
#  ['person1260004', 'rdf:type', 'schema:Person'],
#  ['person1260004', 'schema:name', 'Tawfeek Barhom'],
#  ['movie437342', 'schema:actor', 'person2264673'],
#  ['person2264673', 'rdf:type', 'schema:Person'],
#  ['person2264673', 'schema:name', 'María Caballero'],
#  ['movie437342', 'schema:actor', 'person4391'],
#  ['person4391', 'rdf:type', 'schema:Person'],
#  ['person4391', 'schema:name', 'Charles Dance'],
#  ['movie437342', 'schema:actor', 'person2440'],
#  ['person2440', 'rdf:type', 'schema:Person'],
#  ['person2440', 'schema:name', 'Bill Nighy'],
#  ['movie437342', 'schema:actor', 'person4481145'],
#  ['person4481145', 'rdf:type', 'schema:Person'],
#  ['person4481145', 'schema:name', 'Nicole Sorace'],
#  ['movie437342', 'schema:actor', 'person2733504'],
#  ['person2733504', 'rdf:type', 'schema:Person'],
#  ['person2733504', 'schema:name', 'Ishtar Currie Wilson'],
#  ['movie437342', 'schema:actor', 'person1790754'],
#  ['person1790754', 'rdf:type', 'schema:Person'],
#  ['person1790754', 'schema:name', 'Andrea Arcangeli'],
#  ['movie437342', 'ex:recommendedFrom', 'movie940721'],
#  ['movie614933', 'rdf:type', 'schema:Movie'],
#  ['movie614933', 'schema:name', 'Atlas'],
#  ['movie614933', 'schema:datePublished', 'published_2024'],
#  ['movie614933', 'schema:aggregateRating', 'avgVote_6.725'],
#  ['movie614933', 'schema:duration', 'runtime120'],
#  ['movie614933', 'ex:popularity', 'popul_7.1533'],
#  ['movie614933', 'ex:originalLanguage', 'en'],
#  ['movie614933', 'ex:originCountry', 'US'],
#  ['movie614933', 'schema:director', 'person132876'],
#  ['person132876', 'rdf:type', 'schema:Person'],
#  ['person132876', 'schema:name', 'Brad Peyton'],
#  ['movie614933', 'schema:actor', 'person16866'],
#  ['person16866', 'rdf:type', 'schema:Person'],
#  ['person16866', 'schema:name', 'Jennifer Lopez'],
#  ['movie614933', 'schema:actor', 'person1489211'],
#  ['person1489211', 'rdf:type', 'schema:Person'],
#  ['person1489211', 'schema:name', 'Simu Liu'],
#  ['movie614933', 'schema:actor', 'person1225953'],
#  ['person1225953', 'rdf:type', 'schema:Person'],
#  ['person1225953', 'schema:name', 'Sterling K. Brown'],
#  ['movie614933', 'schema:actor', 'person1970662'],
#  ['person1970662', 'rdf:type', 'schema:Person'],
#  ['person1970662', 'schema:name', 'Gregory James Cohan'],
#  ['movie614933', 'schema:actor', 'person1432064'],
#  ['person1432064', 'rdf:type', 'schema:Person'],
#  ['person1432064', 'schema:name', 'Abraham Popoola'],
#  ['movie614933', 'schema:actor', 'person177231'],
#  ['person177231', 'rdf:type', 'schema:Person'],
#  ['person177231', 'schema:name', 'Lana Parrilla'],
#  ['movie614933', 'schema:actor', 'person2983'],
#  ['person2983', 'rdf:type', 'schema:Person'],
#  ['person2983', 'schema:name', 'Mark Strong'],
#  ['movie614933', 'schema:actor', 'person3314044'],
#  ['person3314044', 'rdf:type', 'schema:Person'],
#  ['person3314044', 'schema:name', 'Briella Guiza'],
#  ['movie614933', 'schema:actor', 'person2504388'],
#  ['person2504388', 'rdf:type', 'schema:Person'],
#  ['person2504388', 'schema:name', 'Adia Smith-Eriksson'],
#  ['movie614933', 'schema:actor', 'person2071572'],
#  ['person2071572', 'rdf:type', 'schema:Person'],
#  ['person2071572', 'schema:name', 'Logan Hunt'],
#  ['movie614933', 'ex:recommendedFrom', 'movie940721'],
#  ['movie1111873', 'rdf:type', 'schema:Movie'],
#  ['movie1111873', 'schema:name', 'Abigail'],
#  ['movie1111873', 'schema:datePublished', 'published_2024'],
#  ['movie1111873', 'schema:aggregateRating', 'avgVote_6.723'],
#  ['movie1111873', 'schema:duration', 'runtime109'],
#  ['movie1111873', 'ex:popularity', 'popul_8.9075'],
#  ['movie1111873', 'ex:originalLanguage', 'en'],
#  ['movie1111873', 'ex:originCountry', 'US'],
#  ['movie1111873', 'schema:director', 'person66681'],
#  ['person66681', 'rdf:type', 'schema:Person'],
#  ['person66681', 'schema:name', 'Matt Bettinelli-Olpin'],
#  ['movie1111873', 'schema:director', 'person1039527'],
#  ['person1039527', 'rdf:type', 'schema:Person'],
#  ['person1039527', 'schema:name', 'Tyler Gillett'],
#  ['movie1111873', 'schema:actor', 'person1373659'],
#  ['person1373659', 'rdf:type', 'schema:Person'],
#  ['person1373659', 'schema:name', 'Melissa Barrera'],
#  ['movie1111873', 'schema:actor', 'person221018'],
#  ['person221018', 'rdf:type', 'schema:Person'],
#  ['person221018', 'schema:name', 'Dan Stevens'],
#  ['movie1111873', 'schema:actor', 'person2442117'],
#  ['person2442117', 'rdf:type', 'schema:Person'],
#  ['person2442117', 'schema:name', 'Alisha Weir'],
#  ['movie1111873', 'schema:actor', 'person1962720'],
#  ['person1962720', 'rdf:type', 'schema:Person'],
#  ['person1962720', 'schema:name', 'William Catlett'],
#  ['movie1111873', 'schema:actor', 'person221192'],
#  ['person221192', 'rdf:type', 'schema:Person'],
#  ['person221192', 'schema:name', 'Kathryn Newton'],
#  ['movie1111873', 'schema:actor', 'person79072'],
#  ['person79072', 'rdf:type', 'schema:Person'],
#  ['person79072', 'schema:name', 'Kevin Durand'],
#  ['movie1111873', 'schema:actor', 'person2352372'],
#  ['person2352372', 'rdf:type', 'schema:Person'],
#  ['person2352372', 'schema:name', 'Angus Cloud'],
#  ['movie1111873', 'schema:actor', 'person4808'],
#  ['person4808', 'rdf:type', 'schema:Person'],
#  ['person4808', 'schema:name', 'Giancarlo Esposito'],
#  ['movie1111873', 'schema:actor', 'person1247'],
#  ['person1247', 'rdf:type', 'schema:Person'],
#  ['person1247', 'schema:name', 'Matthew Goode'],
#  ['movie1111873', 'ex:recommendedFrom', 'movie940721'],
#  ['movie967847', 'rdf:type', 'schema:Movie'],
#  ['movie967847', 'schema:name', 'Ghostbusters: Frozen Empire'],
#  ['movie967847', 'schema:datePublished', 'published_2024'],
#  ['movie967847', 'schema:aggregateRating', 'avgVote_6.472'],
#  ['movie967847', 'schema:duration', 'runtime115'],
#  ['movie967847', 'ex:popularity', 'popul_6.4411'],
#  ['movie967847', 'ex:originalLanguage', 'en'],
#  ['movie967847', 'ex:originCountry', 'US'],
#  ['movie967847', 'schema:director', 'person57193'],
#  ['person57193', 'rdf:type', 'schema:Person'],
#  ['person57193', 'schema:name', 'Gil Kenan'],
#  ['movie967847', 'schema:actor', 'person1172108'],
#  ['person1172108', 'rdf:type', 'schema:Person'],
#  ['person1172108', 'schema:name', 'Mckenna Grace'],
#  ['movie967847', 'schema:actor', 'person22226'],
#  ['person22226', 'rdf:type', 'schema:Person'],
#  ['person22226', 'schema:name', 'Paul Rudd'],
#  ['movie967847', 'schema:actor', 'person1308445'],
#  ['person1308445', 'rdf:type', 'schema:Person'],
#  ['person1308445', 'schema:name', 'Carrie Coon'],
#  ['movie967847', 'schema:actor', 'person1442069'],
#  ['person1442069', 'rdf:type', 'schema:Person'],
#  ['person1442069', 'schema:name', 'Finn Wolfhard'],
#  ['movie967847', 'schema:actor', 'person707'],
#  ['person707', 'rdf:type', 'schema:Person'],
#  ['person707', 'schema:name', 'Dan Aykroyd'],
#  ['movie967847', 'schema:actor', 'person466505'],
#  ['person466505', 'rdf:type', 'schema:Person'],
#  ['person466505', 'schema:name', 'Kumail Nanjiani'],
#  ['movie967847', 'schema:actor', 'person10872'],
#  ['person10872', 'rdf:type', 'schema:Person'],
#  ['person10872', 'schema:name', 'Patton Oswalt'],
#  ['movie967847', 'schema:actor', 'person1972881'],
#  ['person1972881', 'rdf:type', 'schema:Person'],
#  ['person1972881', 'schema:name', "Celeste O'Connor"],
#  ['movie967847', 'schema:actor', 'person2357412'],
#  ['person2357412', 'rdf:type', 'schema:Person'],
#  ['person2357412', 'schema:name', 'Logan Kim'],
#  ['movie967847', 'schema:actor', 'person112742'],
#  ['person112742', 'rdf:type', 'schema:Person'],
#  ['person112742', 'schema:name', 'Emily Alyn Lind'],
#  ['movie967847', 'ex:recommendedFrom', 'movie940721'],
#  ['movie653346', 'rdf:type', 'schema:Movie'],
#  ['movie653346', 'schema:name', 'Kingdom of the Planet of the Apes'],
#  ['movie653346', 'schema:datePublished', 'published_2024'],
#  ['movie653346', 'schema:aggregateRating', 'avgVote_7.1'],
#  ['movie653346', 'schema:duration', 'runtime145'],
#  ['movie653346', 'ex:popularity', 'popul_12.8776'],
#  ['movie653346', 'ex:originalLanguage', 'en'],
#  ['movie653346', 'ex:originCountry', 'US'],
#  ['movie653346', 'schema:director', 'person1179066'],
#  ['person1179066', 'rdf:type', 'schema:Person'],
#  ['person1179066', 'schema:name', 'Wes Ball'],
#  ['movie653346', 'schema:actor', 'person1586047'],
#  ['person1586047', 'rdf:type', 'schema:Person'],
#  ['person1586047', 'schema:name', 'Owen Teague'],
#  ['movie653346', 'schema:actor', 'person2146942'],
#  ['person2146942', 'rdf:type', 'schema:Person'],
#  ['person2146942', 'schema:name', 'Freya Allan'],
#  ['movie653346', 'schema:actor', 'person79072'],
#  ['person79072', 'rdf:type', 'schema:Person'],
#  ['person79072', 'schema:name', 'Kevin Durand'],
#  ['movie653346', 'schema:actor', 'person1444816'],
#  ['person1444816', 'rdf:type', 'schema:Person'],
#  ['person1444816', 'schema:name', 'Peter Macon'],
#  ['movie653346', 'schema:actor', 'person3905'],
#  ['person3905', 'rdf:type', 'schema:Person'],
#  ['person3905', 'schema:name', 'William H. Macy'],
#  ['movie653346', 'schema:actor', 'person966554'],
#  ['person966554', 'rdf:type', 'schema:Person'],
#  ['person966554', 'schema:name', 'Eka Darville'],
#  ['movie653346', 'schema:actor', 'person1394427'],
#  ['person1394427', 'rdf:type', 'schema:Person'],
#  ['person1394427', 'schema:name', 'Travis Jeffery'],
#  ['movie653346', 'schema:actor', 'person2435321'],
#  ['person2435321', 'rdf:type', 'schema:Person'],
#  ['person2435321', 'schema:name', 'Lydia Peckham'],
#  ['movie653346', 'schema:actor', 'person136295'],
#  ['person136295', 'rdf:type', 'schema:Person'],
#  ['person136295', 'schema:name', 'Neil Sandilands'],
#  ['movie653346', 'schema:actor', 'person3757983'],
#  ['person3757983', 'rdf:type', 'schema:Person'],
#  ['person3757983', 'schema:name', "Ras-Samuel Welda'abzgi"],
#  ['movie653346', 'ex:recommendedFrom', 'movie940721'],
#  ['movie799583', 'rdf:type', 'schema:Movie'],
#  ['movie799583', 'schema:name', 'The Ministry of Ungentlemanly Warfare'],
#  ['movie799583', 'schema:datePublished', 'published_2024'],
#  ['movie799583', 'schema:aggregateRating', 'avgVote_7.075'],
#  ['movie799583', 'schema:duration', 'runtime120'],
#  ['movie799583', 'ex:popularity', 'popul_10.9473'],
#  ['movie799583', 'ex:originalLanguage', 'en'],
#  ['movie799583', 'ex:originCountry', 'US'],
#  ['movie799583', 'schema:director', 'person956'],
#  ['person956', 'rdf:type', 'schema:Person'],
#  ['person956', 'schema:name', 'Guy Ritchie'],
#  ['movie799583', 'schema:actor', 'person73968'],
#  ['person73968', 'rdf:type', 'schema:Person'],
#  ['person73968', 'schema:name', 'Henry Cavill'],
#  ['movie799583', 'schema:actor', 'person1222992'],
#  ['person1222992', 'rdf:type', 'schema:Person'],
#  ['person1222992', 'schema:name', 'Eiza González'],
#  ['movie799583', 'schema:actor', 'person64295'],
#  ['person64295', 'rdf:type', 'schema:Person'],
#  ['person64295', 'schema:name', 'Alan Ritchson'],
#  ['movie799583', 'schema:actor', 'person1807132'],
#  ['person1807132', 'rdf:type', 'schema:Person'],
#  ['person1807132', 'schema:name', 'Henry Golding'],
#  ['movie799583', 'schema:actor', 'person2130'],
#  ['person2130', 'rdf:type', 'schema:Person'],
#  ['person2130', 'schema:name', 'Cary Elwes'],
#  ['movie799583', 'schema:actor', 'person61363'],
#  ['person61363', 'rdf:type', 'schema:Person'],
#  ['person61363', 'schema:name', 'Alex Pettyfer'],
#  ['movie799583', 'schema:actor', 'person1114487'],
#  ['person1114487', 'rdf:type', 'schema:Person'],
#  ['person1114487', 'schema:name', 'Hero Fiennes Tiffin'],
#  ['movie799583', 'schema:actor', 'person205923'],
#  ['person205923', 'rdf:type', 'schema:Person'],
#  ['person205923', 'schema:name', 'Babs Olusanmokun'],
#  ['movie799583', 'schema:actor', 'person1563169'],
#  ['person1563169', 'rdf:type', 'schema:Person'],
#  ['person1563169', 'schema:name', 'Henry Zaga'],
#  ['movie799583', 'schema:actor', 'person1844'],
#  ['person1844', 'rdf:type', 'schema:Person'],
#  ['person1844', 'schema:name', 'Til Schweiger'],
#  ['movie799583', 'ex:recommendedFrom', 'movie940721'],
#  ['movie816741', 'rdf:type', 'schema:Movie'],
#  ['movie816741', 'schema:name', 'Grey Eyes'],
#  ['movie816741', 'schema:datePublished', 'published_2018'],
#  ['movie816741', 'schema:aggregateRating', 'avgVote_5.8'],
#  ['movie816741', 'schema:duration', 'runtime100'],
#  ['movie816741', 'ex:popularity', 'popul_2.7275'],
#  ['movie816741', 'ex:originalLanguage', 'es'],
#  ['movie816741', 'ex:originCountry', 'ES'],
#  ['movie816741', 'schema:director', 'person1494770'],
#  ['person1494770', 'rdf:type', 'schema:Person'],
#  ['person1494770', 'schema:name', 'Santiago Ventura'],
#  ['movie816741', 'schema:actor', 'person1348750'],
#  ['person1348750', 'rdf:type', 'schema:Person'],
#  ['person1348750', 'schema:name', 'William Prociuk'],
#  ['movie816741', 'schema:actor', 'person3451017'],
#  ['person3451017', 'rdf:type', 'schema:Person'],
#  ['person3451017', 'schema:name', 'Fernando Amaral'],
#  ['movie816741', 'schema:actor', 'person3023434'],
#  ['person3023434', 'rdf:type', 'schema:Person'],
#  ['person3023434', 'schema:name', 'Cecilia Milano'],
#  ['movie816741', 'schema:actor', 'person1669337'],
#  ['person1669337', 'rdf:type', 'schema:Person'],
#  ['person1669337', 'schema:name', 'Christian Zagia'],
#  ['movie816741', 'schema:actor', 'person1050051'],
#  ['person1050051', 'rdf:type', 'schema:Person'],
#  ['person1050051', 'schema:name', 'Rafael Soliwoda'],
#  ['movie816741', 'schema:actor', 'person3263520'],
#  ['person3263520', 'rdf:type', 'schema:Person'],
#  ['person3263520', 'schema:name', 'Fiorella Bottaioli'],
#  ['movie816741', 'ex:recommendedFrom', 'movie940721'],
#  ['movie843527', 'rdf:type', 'schema:Movie'],
#  ['movie843527', 'schema:name', 'The Idea of You'],
#  ['movie843527', 'schema:datePublished', 'published_2024'],
#  ['movie843527', 'schema:aggregateRating', 'avgVote_7.4'],
#  ['movie843527', 'schema:duration', 'runtime116'],
#  ['movie843527', 'ex:popularity', 'popul_13.1029'],
#  ['movie843527', 'ex:originalLanguage', 'en'],
#  ['movie843527', 'ex:originCountry', 'US'],
#  ['movie843527', 'schema:director', 'person22215'],
#  ['person22215', 'rdf:type', 'schema:Person'],
#  ['person22215', 'schema:name', 'Michael Showalter'],
#  ['movie843527', 'schema:actor', 'person1813'],
#  ['person1813', 'rdf:type', 'schema:Person'],
#  ['person1813', 'schema:name', 'Anne Hathaway'],
#  ['movie843527', 'schema:actor', 'person1425934'],
#  ['person1425934', 'rdf:type', 'schema:Person'],
#  ['person1425934', 'schema:name', 'Nicholas Galitzine'],
#  ['movie843527', 'schema:actor', 'person3307906'],
#  ['person3307906', 'rdf:type', 'schema:Person'],
#  ['person3307906', 'schema:name', 'Ella Rubin'],
#  ['movie843527', 'schema:actor', 'person174514'],
#  ['person174514', 'rdf:type', 'schema:Person'],
#  ['person174514', 'schema:name', 'Annie Mumolo'],
#  ['movie843527', 'schema:actor', 'person81316'],
#  ['person81316', 'rdf:type', 'schema:Person'],
#  ['person81316', 'schema:name', 'Reid Scott'],
#  ['movie843527', 'schema:actor', 'person1869253'],
#  ['person1869253', 'rdf:type', 'schema:Person'],
#  ['person1869253', 'schema:name', 'Perry Mattfeld'],
#  ['movie843527', 'schema:actor', 'person2712164'],
#  ['person2712164', 'rdf:type', 'schema:Person'],
#  ['person2712164', 'schema:name', 'Jordan Aaron Hall'],
#  ['movie843527', 'schema:actor', 'person4574592'],
#  ['person4574592', 'rdf:type', 'schema:Person'],
#  ['person4574592', 'schema:name', 'Mathilda Gianopoulos'],
#  ['movie843527', 'schema:actor', 'person2461728'],
#  ['person2461728', 'rdf:type', 'schema:Person'],
#  ['person2461728', 'schema:name', 'Meg Millidge'],
#  ['movie843527', 'schema:actor', 'person2450847'],
#  ['person2450847', 'rdf:type', 'schema:Person'],
#  ['person2450847', 'schema:name', 'Cheech Manohar'],
#  ['movie843527', 'ex:recommendedFrom', 'movie940721'],
#  ['movie670292', 'rdf:type', 'schema:Movie'],
#  ['movie670292', 'schema:name', 'The Creator'],
#  ['movie670292', 'schema:datePublished', 'published_2023'],
#  ['movie670292', 'schema:aggregateRating', 'avgVote_7.035'],
#  ['movie670292', 'schema:duration', 'runtime134'],
#  ['movie670292', 'ex:popularity', 'popul_9.6203'],
#  ['movie670292', 'ex:originalLanguage', 'en'],
#  ['movie670292', 'ex:originCountry', 'US'],
#  ['movie670292', 'schema:director', 'person129894'],
#  ['person129894', 'rdf:type', 'schema:Person'],
#  ['person129894', 'schema:name', 'Gareth Edwards'],
#  ['movie670292', 'schema:actor', 'person1117313'],
#  ['person1117313', 'rdf:type', 'schema:Person'],
#  ['person1117313', 'schema:name', 'John David Washington'],
#  ['movie670292', 'schema:actor', 'person4068148'],
#  ['person4068148', 'rdf:type', 'schema:Person'],
#  ['person4068148', 'schema:name', 'Madeleine Yuna Voyles'],
#  ['movie670292', 'schema:actor', 'person97576'],
#  ['person97576', 'rdf:type', 'schema:Person'],
#  ['person97576', 'schema:name', 'Gemma Chan'],
#  ['movie670292', 'schema:actor', 'person19'],
#  ['person19', 'rdf:type', 'schema:Person'],
#  ['person19', 'schema:name', 'Allison Janney'],
#  ['movie670292', 'schema:actor', 'person3899'],
#  ['person3899', 'rdf:type', 'schema:Person'],
#  ['person3899', 'schema:name', 'Ken Watanabe'],
#  ['movie670292', 'schema:actor', 'person1526793'],
#  ['person1526793', 'rdf:type', 'schema:Person'],
#  ['person1526793', 'schema:name', 'Sturgill Simpson'],
#  ['movie670292', 'schema:actor', 'person1616920'],
#  ['person1616920', 'rdf:type', 'schema:Person'],
#  ['person1616920', 'schema:name', 'Amar Chadha-Patel'],
#  ['movie670292', 'schema:actor', 'person212776'],
#  ['person212776', 'rdf:type', 'schema:Person'],
#  ['person212776', 'schema:name', 'Marc Menchaca'],
#  ['movie670292', 'schema:actor', 'person1636654'],
#  ['person1636654', 'rdf:type', 'schema:Person'],
#  ['person1636654', 'schema:name', 'Robbie Tann'],
#  ['movie670292', 'schema:actor', 'person202032'],
#  ['person202032', 'rdf:type', 'schema:Person'],
#  ['person202032', 'schema:name', 'Ralph Ineson'],
#  ['movie670292', 'ex:recommendedFrom', 'movie872585'],
#  ['movie575264', 'rdf:type', 'schema:Movie'],
#  ['movie575264',
#   'schema:name',
#   'Mission: Impossible - Dead Reckoning Part One'],
#  ['movie575264', 'schema:datePublished', 'published_2023'],
#  ['movie575264', 'schema:aggregateRating', 'avgVote_7.521'],
#  ['movie575264', 'schema:duration', 'runtime164'],
#  ['movie575264', 'ex:popularity', 'popul_18.1893'],
#  ['movie575264', 'ex:originalLanguage', 'en'],
#  ['movie575264', 'ex:originCountry', 'US'],
#  ['movie575264', 'schema:director', 'person9033'],
#  ['person9033', 'rdf:type', 'schema:Person'],
#  ['person9033', 'schema:name', 'Christopher McQuarrie'],
#  ['movie575264', 'schema:actor', 'person500'],
#  ['person500', 'rdf:type', 'schema:Person'],
#  ['person500', 'schema:name', 'Tom Cruise'],
#  ['movie575264', 'schema:actor', 'person39459'],
#  ['person39459', 'rdf:type', 'schema:Person'],
#  ['person39459', 'schema:name', 'Hayley Atwell'],
#  ['movie575264', 'schema:actor', 'person10182'],
#  ['person10182', 'rdf:type', 'schema:Person'],
#  ['person10182', 'schema:name', 'Ving Rhames'],
#  ['movie575264', 'schema:actor', 'person11108'],
#  ['person11108', 'rdf:type', 'schema:Person'],
#  ['person11108', 'schema:name', 'Simon Pegg'],
#  ['movie575264', 'schema:actor', 'person933238'],
#  ['person933238', 'rdf:type', 'schema:Person'],
#  ['person933238', 'schema:name', 'Rebecca Ferguson'],
#  ['movie575264', 'schema:actor', 'person556356'],
#  ['person556356', 'rdf:type', 'schema:Person'],
#  ['person556356', 'schema:name', 'Vanessa Kirby'],
#  ['movie575264', 'schema:actor', 'person65344'],
#  ['person65344', 'rdf:type', 'schema:Person'],
#  ['person65344', 'schema:name', 'Esai Morales'],
#  ['movie575264', 'schema:actor', 'person139820'],
#  ['person139820', 'rdf:type', 'schema:Person'],
#  ['person139820', 'schema:name', 'Pom Klementieff'],
#  ['movie575264', 'schema:actor', 'person15319'],
#  ['person15319', 'rdf:type', 'schema:Person'],
#  ['person15319', 'schema:name', 'Henry Czerny'],
#  ['movie575264', 'schema:actor', 'person74242'],
#  ['person74242', 'rdf:type', 'schema:Person'],
#  ['person74242', 'schema:name', 'Shea Whigham'],
#  ['movie575264', 'ex:recommendedFrom', 'movie872585'],
#  ['movie466420', 'rdf:type', 'schema:Movie'],
#  ['movie466420', 'schema:name', 'Killers of the Flower Moon'],
#  ['movie466420', 'schema:datePublished', 'published_2023'],
#  ['movie466420', 'schema:aggregateRating', 'avgVote_7.414'],
#  ['movie466420', 'schema:duration', 'runtime206'],
#  ['movie466420', 'ex:popularity', 'popul_10.82'],
#  ['movie466420', 'ex:originalLanguage', 'en'],
#  ['movie466420', 'ex:originCountry', 'US'],
#  ['movie466420', 'schema:director', 'person1032'],
#  ['person1032', 'rdf:type', 'schema:Person'],
#  ['person1032', 'schema:name', 'Martin Scorsese'],
#  ['movie466420', 'schema:actor', 'person6193'],
#  ['person6193', 'rdf:type', 'schema:Person'],
#  ['person6193', 'schema:name', 'Leonardo DiCaprio'],
#  ['movie466420', 'schema:actor', 'person380'],
#  ['person380', 'rdf:type', 'schema:Person'],
#  ['person380', 'schema:name', 'Robert De Niro'],
#  ['movie466420', 'schema:actor', 'person1183917'],
#  ['person1183917', 'rdf:type', 'schema:Person'],
#  ['person1183917', 'schema:name', 'Lily Gladstone'],
#  ['movie466420', 'schema:actor', 'person88124'],
#  ['person88124', 'rdf:type', 'schema:Person'],
#  ['person88124', 'schema:name', 'Jesse Plemons'],
#  ['movie466420', 'schema:actor', 'person7863'],
#  ['person7863', 'rdf:type', 'schema:Person'],
#  ['person7863', 'schema:name', 'Tantoo Cardinal'],
#  ['movie466420', 'schema:actor', 'person12074'],
#  ['person12074', 'rdf:type', 'schema:Person'],
#  ['person12074', 'schema:name', 'John Lithgow'],
#  ['movie466420', 'schema:actor', 'person18269'],
#  ['person18269', 'rdf:type', 'schema:Person'],
#  ['person18269', 'schema:name', 'Brendan Fraser'],
#  ['movie466420', 'schema:actor', 'person3006897'],
#  ['person3006897', 'rdf:type', 'schema:Person'],
#  ['person3006897', 'schema:name', 'Cara Jade Myers'],
#  ['movie466420', 'schema:actor', 'person3006898'],
#  ['person3006898', 'rdf:type', 'schema:Person'],
#  ['person3006898', 'schema:name', 'JaNae Collins'],
#  ['movie466420', 'schema:actor', 'person2698946'],
#  ['person2698946', 'rdf:type', 'schema:Person'],
#  ['person2698946', 'schema:name', 'Jillian Dion'],
#  ['movie466420', 'ex:recommendedFrom', 'movie872585'],
#  ['movie753342', 'rdf:type', 'schema:Movie'],
#  ['movie753342', 'schema:name', 'Napoleon'],
#  ['movie753342', 'schema:datePublished', 'published_2023'],
#  ['movie753342', 'schema:aggregateRating', 'avgVote_6.326'],
#  ['movie753342', 'schema:duration', 'runtime158'],
#  ['movie753342', 'ex:popularity', 'popul_10.5622'],
#  ['movie753342', 'ex:originalLanguage', 'en'],
#  ['movie753342', 'ex:originCountry', 'US'],
#  ['movie753342', 'schema:director', 'person578'],
#  ['person578', 'rdf:type', 'schema:Person'],
#  ['person578', 'schema:name', 'Ridley Scott'],
#  ['movie753342', 'schema:actor', 'person73421'],
#  ['person73421', 'rdf:type', 'schema:Person'],
#  ['person73421', 'schema:name', 'Joaquin Phoenix'],
#  ['movie753342', 'schema:actor', 'person556356'],
#  ['person556356', 'rdf:type', 'schema:Person'],
#  ['person556356', 'schema:name', 'Vanessa Kirby'],
#  ['movie753342', 'schema:actor', 'person81051'],
#  ['person81051', 'rdf:type', 'schema:Person'],
#  ['person81051', 'schema:name', 'Tahar Rahim'],
#  ['movie753342', 'schema:actor', 'person4757'],
#  ['person4757', 'rdf:type', 'schema:Person'],
#  ['person4757', 'schema:name', 'Rupert Everett'],
#  ['movie753342', 'schema:actor', 'person1231402'],
#  ['person1231402', 'rdf:type', 'schema:Person'],
#  ['person1231402', 'schema:name', 'Mark Bonnar'],
#  ['movie753342', 'schema:actor', 'person80365'],
#  ['person80365', 'rdf:type', 'schema:Person'],
#  ['person80365', 'schema:name', 'Paul Rhys'],
#  ['movie753342', 'schema:actor', 'person11280'],
#  ['person11280', 'rdf:type', 'schema:Person'],
#  ['person11280', 'schema:name', 'Ben Miles'],
#  ['movie753342', 'schema:actor', 'person2599915'],
#  ['person2599915', 'rdf:type', 'schema:Person'],
#  ['person2599915', 'schema:name', 'Riana Duce'],
#  ['movie753342', 'schema:actor', 'person1700994'],
#  ['person1700994', 'rdf:type', 'schema:Person'],
#  ['person1700994', 'schema:name', 'Edouard Philipponnat'],
#  ['movie753342', 'schema:actor', 'person221857'],
#  ['person221857', 'rdf:type', 'schema:Person'],
#  ['person221857', 'schema:name', 'Miles Jupp'],
#  ['movie753342', 'ex:recommendedFrom', 'movie872585'],
#  ['movie792307', 'rdf:type', 'schema:Movie'],
#  ['movie792307', 'schema:name', 'Poor Things'],
#  ['movie792307', 'schema:datePublished', 'published_2023'],
#  ['movie792307', 'schema:aggregateRating', 'avgVote_7.7'],
#  ['movie792307', 'schema:duration', 'runtime141'],
#  ['movie792307', 'ex:popularity', 'popul_13.4753'],
#  ['movie792307', 'ex:originalLanguage', 'en'],
#  ['movie792307', 'ex:originCountry', 'US'],
#  ['movie792307', 'schema:director', 'person122423'],
#  ['person122423', 'rdf:type', 'schema:Person'],
#  ['person122423', 'schema:name', 'Yorgos Lanthimos'],
#  ['movie792307', 'schema:actor', 'person54693'],
#  ['person54693', 'rdf:type', 'schema:Person'],
#  ['person54693', 'schema:name', 'Emma Stone'],
#  ['movie792307', 'schema:actor', 'person103'],
#  ['person103', 'rdf:type', 'schema:Person'],
#  ['person103', 'schema:name', 'Mark Ruffalo'],
#  ['movie792307', 'schema:actor', 'person5293'],
#  ['person5293', 'rdf:type', 'schema:Person'],
#  ['person5293', 'schema:name', 'Willem Dafoe'],
#  ['movie792307', 'schema:actor', 'person1382987'],
#  ['person1382987', 'rdf:type', 'schema:Person'],
#  ['person1382987', 'schema:name', 'Ramy Youssef'],
#  ['movie792307', 'schema:actor', 'person984629'],
#  ['person984629', 'rdf:type', 'schema:Person'],
#  ['person984629', 'schema:name', 'Christopher Abbott'],
#  ['movie792307', 'schema:actor', 'person2331794'],
#  ['person2331794', 'rdf:type', 'schema:Person'],
#  ['person2331794', 'schema:name', 'Suzy Bemba'],
#  ['movie792307', 'schema:actor', 'person1400880'],
#  ['person1400880', 'rdf:type', 'schema:Person'],
#  ['person1400880', 'schema:name', 'Jerrod Carmichael'],
#  ['movie792307', 'schema:actor', 'person72309'],
#  ['person72309', 'rdf:type', 'schema:Person'],
#  ['person72309', 'schema:name', 'Kathryn Hunter'],
#  ['movie792307', 'schema:actor', 'person1248292'],
#  ['person1248292', 'rdf:type', 'schema:Person'],
#  ['person1248292', 'schema:name', 'Vicki Pepperdine'],
#  ['movie792307', 'schema:actor', 'person3734'],
#  ['person3734', 'rdf:type', 'schema:Person'],
#  ['person3734', 'schema:name', 'Hanna Schygulla'],
#  ['movie792307', 'ex:recommendedFrom', 'movie872585'],
#  ['movie937746', 'rdf:type', 'schema:Movie'],
#  ['movie937746', 'schema:name', 'Io Capitano'],
#  ['movie937746', 'schema:datePublished', 'published_2023'],
#  ['movie937746', 'schema:aggregateRating', 'avgVote_7.8'],
#  ['movie937746', 'schema:duration', 'runtime121'],
#  ['movie937746', 'ex:popularity', 'popul_2.8664'],
#  ['movie937746', 'ex:originalLanguage', 'it'],
#  ['movie937746', 'ex:originCountry', 'IT'],
#  ['movie937746', 'schema:director', 'person63973'],
#  ['person63973', 'rdf:type', 'schema:Person'],
#  ['person63973', 'schema:name', 'Matteo Garrone'],
#  ['movie937746', 'schema:actor', 'person3626193'],
#  ['person3626193', 'rdf:type', 'schema:Person'],
#  ['person3626193', 'schema:name', 'Seydou Sarr'],
#  ['movie937746', 'schema:actor', 'person3626194'],
#  ['person3626194', 'rdf:type', 'schema:Person'],
#  ['person3626194', 'schema:name', 'Moustapha Fall'],
#  ['movie937746', 'schema:actor', 'person23301'],
#  ['person23301', 'rdf:type', 'schema:Person'],
#  ['person23301', 'schema:name', 'Issaka Sawadogo'],
#  ['movie937746', 'schema:actor', 'person89625'],
#  ['person89625', 'rdf:type', 'schema:Person'],
#  ['person89625', 'schema:name', 'Hichem Yacoubi'],
#  ['movie937746', 'schema:actor', 'person4264688'],
#  ['person4264688', 'rdf:type', 'schema:Person'],
#  ['person4264688', 'schema:name', 'Doodou Sagna'],
#  ['movie937746', 'schema:actor', 'person4264689'],
#  ['person4264689', 'rdf:type', 'schema:Person'],
#  ['person4264689', 'schema:name', 'Khady Sy'],
#  ['movie937746', 'schema:actor', 'person4264691'],
#  ['person4264691', 'rdf:type', 'schema:Person'],
#  ['person4264691', 'schema:name', 'Venus Gueye'],
#  ['movie937746', 'schema:actor', 'person4264692'],
#  ['person4264692', 'rdf:type', 'schema:Person'],
#  ['person4264692', 'schema:name', 'Cheick Oumar Diaw'],
#  ['movie937746', 'schema:actor', 'person4439793'],
#  ['person4439793', 'rdf:type', 'schema:Person'],
#  ['person4439793', 'schema:name', 'Joe Lassana'],
#  ['movie937746', 'schema:actor', 'person4439797'],
#  ['person4439797', 'rdf:type', 'schema:Person'],
#  ['person4439797', 'schema:name', 'Mamadou Sani'],
#  ['movie937746', 'ex:recommendedFrom', 'movie872585'],
#  ['movie945729', 'rdf:type', 'schema:Movie'],
#  ['movie945729', 'schema:name', 'A Haunting in Venice'],
#  ['movie945729', 'schema:datePublished', 'published_2023'],
#  ['movie945729', 'schema:aggregateRating', 'avgVote_6.588'],
#  ['movie945729', 'schema:duration', 'runtime104'],
#  ['movie945729', 'ex:popularity', 'popul_6.8661'],
#  ['movie945729', 'ex:originalLanguage', 'en'],
#  ['movie945729', 'ex:originCountry', 'GB'],
#  ['movie945729', 'ex:originCountry', 'US'],
#  ['movie945729', 'schema:director', 'person11181'],
#  ['person11181', 'rdf:type', 'schema:Person'],
#  ['person11181', 'schema:name', 'Kenneth Branagh'],
#  ['movie945729', 'schema:actor', 'person11181'],
#  ['person11181', 'rdf:type', 'schema:Person'],
#  ['person11181', 'schema:name', 'Kenneth Branagh'],
#  ['movie945729', 'schema:actor', 'person1562074'],
#  ['person1562074', 'rdf:type', 'schema:Person'],
#  ['person1562074', 'schema:name', 'Kyle Allen'],
#  ['movie945729', 'schema:actor', 'person1348474'],
#  ['person1348474', 'rdf:type', 'schema:Person'],
#  ['person1348474', 'schema:name', 'Camille Cottin'],
#  ['movie945729', 'schema:actor', 'person1254583'],
#  ['person1254583', 'rdf:type', 'schema:Person'],
#  ['person1254583', 'schema:name', 'Jamie Dornan'],
#  ['movie945729', 'schema:actor', 'person56323'],
#  ['person56323', 'rdf:type', 'schema:Person'],
#  ['person56323', 'schema:name', 'Tina Fey'],
#  ['movie945729', 'schema:actor', 'person3232669'],
#  ['person3232669', 'rdf:type', 'schema:Person'],
#  ['person3232669', 'schema:name', 'Jude Hill'],
#  ['movie945729', 'schema:actor', 'person2104805'],
#  ['person2104805', 'rdf:type', 'schema:Person'],
#  ['person2104805', 'schema:name', 'Ali Khan'],
#  ['movie945729', 'schema:actor', 'person2290611'],
#  ['person2290611', 'rdf:type', 'schema:Person'],
#  ['person2290611', 'schema:name', 'Emma Laird'],
#  ['movie945729', 'schema:actor', 'person17521'],
#  ['person17521', 'rdf:type', 'schema:Person'],
#  ['person17521', 'schema:name', 'Kelly Reilly'],
#  ['movie945729', 'schema:actor', 'person59270'],
#  ['person59270', 'rdf:type', 'schema:Person'],
#  ['person59270', 'schema:name', 'Riccardo Scamarcio'],
#  ['movie945729', 'ex:recommendedFrom', 'movie872585'],
#  ['movie507089', 'rdf:type', 'schema:Movie'],
#  ['movie507089', 'schema:name', "Five Nights at Freddy's"],
#  ['movie507089', 'schema:datePublished', 'published_2023'],
#  ['movie507089', 'schema:aggregateRating', 'avgVote_7.399'],
#  ['movie507089', 'schema:duration', 'runtime110'],
#  ['movie507089', 'ex:popularity', 'popul_10.4017'],
#  ['movie507089', 'ex:originalLanguage', 'en'],
#  ['movie507089', 'ex:originCountry', 'US'],
#  ['movie507089', 'schema:director', 'person2103746'],
#  ['person2103746', 'rdf:type', 'schema:Person'],
#  ['person2103746', 'schema:name', 'Emma Tammi'],
#  ['movie507089', 'schema:actor', 'person27972'],
#  ['person27972', 'rdf:type', 'schema:Person'],
#  ['person27972', 'schema:name', 'Josh Hutcherson'],
#  ['movie507089', 'schema:actor', 'person2283930'],
#  ['person2283930', 'rdf:type', 'schema:Person'],
#  ['person2283930', 'schema:name', 'Piper Rubio'],
#  ['movie507089', 'schema:actor', 'person1368507'],
#  ['person1368507', 'rdf:type', 'schema:Person'],
#  ['person1368507', 'schema:name', 'Elizabeth Lail'],
#  ['movie507089', 'schema:actor', 'person26457'],
#  ['person26457', 'rdf:type', 'schema:Person'],
#  ['person26457', 'schema:name', 'Matthew Lillard'],
#  ['movie507089', 'schema:actor', 'person31140'],
#  ['person31140', 'rdf:type', 'schema:Person'],
#  ['person31140', 'schema:name', 'Mary Stuart Masterson'],
#  ['movie507089', 'schema:actor', 'person2620732'],
#  ['person2620732', 'rdf:type', 'schema:Person'],
#  ['person2620732', 'schema:name', 'Kat Conner Sterling'],
#  ['movie507089', 'schema:actor', 'person2865624'],
#  ['person2865624', 'rdf:type', 'schema:Person'],
#  ['person2865624', 'schema:name', 'David Lind'],
#  ['movie507089', 'schema:actor', 'person575674'],
#  ['person575674', 'rdf:type', 'schema:Person'],
#  ['person575674', 'schema:name', 'Christian Stokes'],
#  ['movie507089', 'schema:actor', 'person1682013'],
#  ['person1682013', 'rdf:type', 'schema:Person'],
#  ['person1682013', 'schema:name', 'Joseph Poliquin'],
#  ['movie507089', 'schema:actor', 'person3277483'],
#  ['person3277483', 'rdf:type', 'schema:Person'],
#  ['person3277483', 'schema:name', 'Grant Feely'],
#  ['movie507089', 'ex:recommendedFrom', 'movie872585'],
#  ['movie976573', 'rdf:type', 'schema:Movie'],
#  ['movie976573', 'schema:name', 'Elemental'],
#  ['movie976573', 'schema:datePublished', 'published_2023'],
#  ['movie976573', 'schema:aggregateRating', 'avgVote_7.6'],
#  ['movie976573', 'schema:duration', 'runtime102'],
#  ['movie976573', 'ex:popularity', 'popul_12.3727'],
#  ['movie976573', 'ex:originalLanguage', 'en'],
#  ['movie976573', 'ex:originCountry', 'US'],
#  ['movie976573', 'schema:director', 'person21198'],
#  ['person21198', 'rdf:type', 'schema:Person'],
#  ['person21198', 'schema:name', 'Peter Sohn'],
#  ['movie976573', 'schema:actor', 'person1087262'],
#  ['person1087262', 'rdf:type', 'schema:Person'],
#  ['person1087262', 'schema:name', 'Leah Lewis'],
#  ['movie976573', 'schema:actor', 'person1639848'],
#  ['person1639848', 'rdf:type', 'schema:Person'],
#  ['person1639848', 'schema:name', 'Mamoudou Athie'],
#  ['movie976573', 'schema:actor', 'person1236458'],
#  ['person1236458', 'rdf:type', 'schema:Person'],
#  ['person1236458', 'schema:name', 'Ronnie del Carmen'],
#  ['movie976573', 'schema:actor', 'person2073564'],
#  ['person2073564', 'rdf:type', 'schema:Person'],
#  ['person2073564', 'schema:name', 'Shila Ommi'],
#  ['movie976573', 'schema:actor', 'person63234'],
#  ['person63234', 'rdf:type', 'schema:Person'],
#  ['person63234', 'schema:name', 'Wendi McLendon-Covey'],
#  ['movie976573', 'schema:actor', 'person11514'],
#  ['person11514', 'rdf:type', 'schema:Person'],
#  ['person11514', 'schema:name', "Catherine O'Hara"],
#  ['movie976573', 'schema:actor', 'person3983226'],
#  ['person3983226', 'rdf:type', 'schema:Person'],
#  ['person3983226', 'schema:name', 'Mason Wertheimer'],
#  ['movie976573', 'schema:actor', 'person1217619'],
#  ['person1217619', 'rdf:type', 'schema:Person'],
#  ['person1217619', 'schema:name', 'Ronobir Lahiri'],
#  ['movie976573', 'schema:actor', 'person1576334'],
#  ['person1576334', 'rdf:type', 'schema:Person'],
#  ['person1576334', 'schema:name', 'Wilma Bonet'],
#  ['movie976573', 'schema:actor', 'person1663974'],
#  ['person1663974', 'rdf:type', 'schema:Person'],
#  ['person1663974', 'schema:name', 'Joe Pera'],
#  ['movie976573', 'ex:recommendedFrom', 'movie346698'],
#  ['movie298618', 'rdf:type', 'schema:Movie'],
#  ['movie298618', 'schema:name', 'The Flash'],
#  ['movie298618', 'schema:datePublished', 'published_2023'],
#  ['movie298618', 'schema:aggregateRating', 'avgVote_6.6'],
#  ['movie298618', 'schema:duration', 'runtime144'],
#  ['movie298618', 'ex:popularity', 'popul_11.3613'],
#  ['movie298618', 'ex:originalLanguage', 'en'],
#  ['movie298618', 'ex:originCountry', 'US'],
#  ['movie298618', 'schema:director', 'person1113116'],
#  ['person1113116', 'rdf:type', 'schema:Person'],
#  ['person1113116', 'schema:name', 'Andy Muschietti'],
#  ['movie298618', 'schema:actor', 'person132157'],
#  ['person132157', 'rdf:type', 'schema:Person'],
#  ['person132157', 'schema:name', 'Ezra Miller'],
#  ['movie298618', 'schema:actor', 'person2542319'],
#  ['person2542319', 'rdf:type', 'schema:Person'],
#  ['person2542319', 'schema:name', 'Sasha Calle'],
#  ['movie298618', 'schema:actor', 'person2232'],
#  ['person2232', 'rdf:type', 'schema:Person'],
#  ['person2232', 'schema:name', 'Michael Keaton'],
#  ['movie298618', 'schema:actor', 'person335'],
#  ['person335', 'rdf:type', 'schema:Person'],
#  ['person335', 'schema:name', 'Michael Shannon'],
#  ['movie298618', 'schema:actor', 'person17402'],
#  ['person17402', 'rdf:type', 'schema:Person'],
#  ['person17402', 'schema:name', 'Ron Livingston'],
#  ['movie298618', 'schema:actor', 'person16971'],
#  ['person16971', 'rdf:type', 'schema:Person'],
#  ['person16971', 'schema:name', 'Maribel Verdú'],
#  ['movie298618', 'schema:actor', 'person1253355'],
#  ['person1253355', 'rdf:type', 'schema:Person'],
#  ['person1253355', 'schema:name', 'Kiersey Clemons'],
#  ['movie298618', 'schema:actor', 'person43202'],
#  ['person43202', 'rdf:type', 'schema:Person'],
#  ['person43202', 'schema:name', 'Antje Traue'],
#  ['movie298618', 'schema:actor', 'person1660888'],
#  ['person1660888', 'rdf:type', 'schema:Person'],
#  ['person1660888', 'schema:name', 'Saoirse-Monica Jackson'],
#  ['movie298618', 'schema:actor', 'person1727045'],
#  ['person1727045', 'rdf:type', 'schema:Person'],
#  ['person1727045', 'schema:name', 'Rudy Mancuso'],
#  ['movie298618', 'ex:recommendedFrom', 'movie346698'],
#  ['movie615656', 'rdf:type', 'schema:Movie'],
#  ['movie615656', 'schema:name', 'Meg 2: The Trench'],
#  ['movie615656', 'schema:datePublished', 'published_2023'],
#  ['movie615656', 'schema:aggregateRating', 'avgVote_6.416'],
#  ['movie615656', 'schema:duration', 'runtime116'],
#  ['movie615656', 'ex:popularity', 'popul_11.9192'],
#  ['movie615656', 'ex:originalLanguage', 'en'],
#  ['movie615656', 'ex:originCountry', 'US'],
#  ['movie615656', 'schema:director', 'person137467'],
#  ['person137467', 'rdf:type', 'schema:Person'],
#  ['person137467', 'schema:name', 'Ben Wheatley'],
#  ['movie615656', 'schema:actor', 'person976'],
#  ['person976', 'rdf:type', 'schema:Person'],
#  ['person976', 'schema:name', 'Jason Statham'],
#  ['movie615656', 'schema:actor', 'person78871'],
#  ['person78871', 'rdf:type', 'schema:Person'],
#  ['person78871', 'schema:name', 'Wu Jing'],
#  ['movie615656', 'schema:actor', 'person1704579'],
#  ['person1704579', 'rdf:type', 'schema:Person'],
#  ['person1704579', 'schema:name', 'Shuya Sophia Cai'],
#  ['movie615656', 'schema:actor', 'person177214'],
#  ['person177214', 'rdf:type', 'schema:Person'],
#  ['person177214', 'schema:name', 'Page Kennedy'],
#  ['movie615656', 'schema:actor', 'person78994'],
#  ['person78994', 'rdf:type', 'schema:Person'],
#  ['person78994', 'schema:name', 'Sergio Peris-Mencheta'],
#  ['movie615656', 'schema:actor', 'person7055'],
#  ['person7055', 'rdf:type', 'schema:Person'],
#  ['person7055', 'schema:name', 'Sienna Guillory'],
#  ['movie615656', 'schema:actor', 'person7248'],
#  ['person7248', 'rdf:type', 'schema:Person'],
#  ['person7248', 'schema:name', 'Cliff Curtis'],
#  ['movie615656', 'schema:actor', 'person110930'],
#  ['person110930', 'rdf:type', 'schema:Person'],
#  ['person110930', 'schema:name', 'Skyler Samuels'],
#  ['movie615656', 'schema:actor', 'person1977759'],
#  ['person1977759', 'rdf:type', 'schema:Person'],
#  ['person1977759', 'schema:name', 'Melissanthi Mahut'],
#  ['movie615656', 'schema:actor', 'person1503556'],
#  ['person1503556', 'rdf:type', 'schema:Person'],
#  ['person1503556', 'schema:name', 'Whoopie van Raam'],
#  ['movie615656', 'ex:recommendedFrom', 'movie346698'],
#  ['movie335977', 'rdf:type', 'schema:Movie'],
#  ['movie335977', 'schema:name', 'Indiana Jones and the Dial of Destiny'],
#  ['movie335977', 'schema:datePublished', 'published_2023'],
#  ['movie335977', 'schema:aggregateRating', 'avgVote_6.541'],
#  ['movie335977', 'schema:duration', 'runtime155'],
#  ['movie335977', 'ex:popularity', 'popul_8.4845'],
#  ['movie335977', 'ex:originalLanguage', 'en'],
#  ['movie335977', 'ex:originCountry', 'US'],
#  ['movie335977', 'schema:director', 'person366'],
#  ['person366', 'rdf:type', 'schema:Person'],
#  ['person366', 'schema:name', 'James Mangold'],
#  ['movie335977', 'schema:actor', 'person3'],
#  ['person3', 'rdf:type', 'schema:Person'],
#  ['person3', 'schema:name', 'Harrison Ford'],
#  ['movie335977', 'schema:actor', 'person1023483'],
#  ['person1023483', 'rdf:type', 'schema:Person'],
#  ['person1023483', 'schema:name', 'Phoebe Waller-Bridge'],
#  ['movie335977', 'schema:actor', 'person1019'],
#  ['person1019', 'rdf:type', 'schema:Person'],
#  ['person1019', 'schema:name', 'Mads Mikkelsen'],
#  ['movie335977', 'schema:actor', 'person467645'],
#  ['person467645', 'rdf:type', 'schema:Person'],
#  ['person467645', 'schema:name', 'Boyd Holbrook'],
#  ['movie335977', 'schema:actor', 'person2074238'],
#  ['person2074238', 'rdf:type', 'schema:Person'],
#  ['person2074238', 'schema:name', 'Olivier Richters'],
#  ['movie335977', 'schema:actor', 'person3810691'],
#  ['person3810691', 'rdf:type', 'schema:Person'],
#  ['person3810691', 'schema:name', 'Ethann Isidore'],
#  ['movie335977', 'schema:actor', 'person13014'],
#  ['person13014', 'rdf:type', 'schema:Person'],
#  ['person13014', 'schema:name', 'Toby Jones'],
#  ['movie335977', 'schema:actor', 'person3131'],
#  ['person3131', 'rdf:type', 'schema:Person'],
#  ['person3131', 'schema:name', 'Antonio Banderas'],
#  ['movie335977', 'schema:actor', 'person650'],
#  ['person650', 'rdf:type', 'schema:Person'],
#  ['person650', 'schema:name', 'Karen Allen'],
#  ['movie335977', 'schema:actor', 'person655'],
#  ['person655', 'rdf:type', 'schema:Person'],
#  ['person655', 'schema:name', 'John Rhys-Davies'],
#  ['movie335977', 'ex:recommendedFrom', 'movie346698'],
#  ['movie447277', 'rdf:type', 'schema:Movie'],
#  ['movie447277', 'schema:name', 'The Little Mermaid'],
#  ['movie447277', 'schema:datePublished', 'published_2023'],
#  ['movie447277', 'schema:aggregateRating', 'avgVote_6.301'],
#  ['movie447277', 'schema:duration', 'runtime135'],
#  ['movie447277', 'ex:popularity', 'popul_7.9083'],
#  ['movie447277', 'ex:originalLanguage', 'en'],
#  ['movie447277', 'ex:originCountry', 'US'],
#  ['movie447277', 'schema:director', 'person17633'],
#  ['person17633', 'rdf:type', 'schema:Person'],
#  ['person17633', 'schema:name', 'Rob Marshall'],
#  ['movie447277', 'schema:actor', 'person1735828'],
#  ['person1735828', 'rdf:type', 'schema:Person'],
#  ['person1735828', 'schema:name', 'Halle Bailey'],
#  ['movie447277', 'schema:actor', 'person1599391'],
#  ['person1599391', 'rdf:type', 'schema:Person'],
#  ['person1599391', 'schema:name', 'Jonah Hauer-King'],
#  ['movie447277', 'schema:actor', 'person55536'],
#  ['person55536', 'rdf:type', 'schema:Person'],
#  ['person55536', 'schema:name', 'Melissa McCarthy'],
#  ['movie447277', 'schema:actor', 'person3810'],
#  ['person3810', 'rdf:type', 'schema:Person'],
#  ['person3810', 'schema:name', 'Javier Bardem'],
#  ['movie447277', 'schema:actor', 'person517103'],
#  ['person517103', 'rdf:type', 'schema:Person'],
#  ['person517103', 'schema:name', 'Noma Dumezweni'],
#  ['movie447277', 'schema:actor', 'person10672'],
#  ['person10672', 'rdf:type', 'schema:Person'],
#  ['person10672', 'schema:name', 'Art Malik'],
#  ['movie447277', 'schema:actor', 'person1652371'],
#  ['person1652371', 'rdf:type', 'schema:Person'],
#  ['person1652371', 'schema:name', 'Daveed Diggs'],
#  ['movie447277', 'schema:actor', 'person1277188'],
#  ['person1277188', 'rdf:type', 'schema:Person'],
#  ['person1277188', 'schema:name', 'Jacob Tremblay'],
#  ['movie447277', 'schema:actor', 'person1625558'],
#  ['person1625558', 'rdf:type', 'schema:Person'],
#  ['person1625558', 'schema:name', 'Awkwafina'],
#  ['movie447277', 'schema:actor', 'person2600509'],
#  ['person2600509', 'rdf:type', 'schema:Person'],
#  ['person2600509', 'schema:name', 'Jessica Alexander'],
#  ['movie447277', 'ex:recommendedFrom', 'movie346698'],
#  ['movie565770', 'rdf:type', 'schema:Movie'],
#  ['movie565770', 'schema:name', 'Blue Beetle'],
#  ['movie565770', 'schema:datePublished', 'published_2023'],
#  ['movie565770', 'schema:aggregateRating', 'avgVote_6.667'],
#  ['movie565770', 'schema:duration', 'runtime128'],
#  ['movie565770', 'ex:popularity', 'popul_11.6004'],
#  ['movie565770', 'ex:originalLanguage', 'en'],
#  ['movie565770', 'ex:originCountry', 'US'],
#  ['movie565770', 'schema:director', 'person1500758'],
#  ['person1500758', 'rdf:type', 'schema:Person'],
#  ['person1500758', 'schema:name', 'Ángel Manuel Soto'],
#  ['movie565770', 'schema:actor', 'person1185997'],
#  ['person1185997', 'rdf:type', 'schema:Person'],
#  ['person1185997', 'schema:name', 'Xolo Mariduena'],
#  ['movie565770', 'schema:actor', 'person1622590'],
#  ['person1622590', 'rdf:type', 'schema:Person'],
#  ['person1622590', 'schema:name', 'Bruna Marquezine'],
#  ['movie565770', 'schema:actor', 'person4038'],
#  ['person4038', 'rdf:type', 'schema:Person'],
#  ['person4038', 'schema:name', 'Susan Sarandon'],
#  ['movie565770', 'schema:actor', 'person17688'],
#  ['person17688', 'rdf:type', 'schema:Person'],
#  ['person17688', 'schema:name', 'Raoul Max Trujillo'],
#  ['movie565770', 'schema:actor', 'person2381442'],
#  ['person2381442', 'rdf:type', 'schema:Person'],
#  ['person2381442', 'schema:name', 'Belissa Escobedo'],
#  ['movie565770', 'schema:actor', 'person7370'],
#  ['person7370', 'rdf:type', 'schema:Person'],
#  ['person7370', 'schema:name', 'Damián Alcázar'],
#  ['movie565770', 'schema:actor', 'person1102'],
#  ['person1102', 'rdf:type', 'schema:Person'],
#  ['person1102', 'schema:name', 'Elpidia Carrillo'],
#  ['movie565770', 'schema:actor', 'person41798'],
#  ['person41798', 'rdf:type', 'schema:Person'],
#  ['person41798', 'schema:name', 'George López'],
#  ['movie565770', 'schema:actor', 'person270'],
#  ['person270', 'rdf:type', 'schema:Person'],
#  ['person270', 'schema:name', 'Adriana Barraza'],
#  ['movie565770', 'schema:actor', 'person1529446'],
#  ['person1529446', 'rdf:type', 'schema:Person'],
#  ['person1529446', 'schema:name', 'Becky G'],
#  ['movie565770', 'ex:recommendedFrom', 'movie346698'],
#  ['movie614930', 'rdf:type', 'schema:Movie'],
#  ['movie614930', 'schema:name', 'Teenage Mutant Ninja Turtles: Mutant Mayhem'],
#  ['movie614930', 'schema:datePublished', 'published_2023'],
#  ['movie614930', 'schema:aggregateRating', 'avgVote_7.209'],
#  ['movie614930', 'schema:duration', 'runtime100'],
#  ['movie614930', 'ex:popularity', 'popul_7.7383'],
#  ['movie614930', 'ex:originalLanguage', 'en'],
#  ['movie614930', 'ex:originCountry', 'US'],
#  ['movie614930', 'schema:director', 'person1578590'],
#  ['person1578590', 'rdf:type', 'schema:Person'],
#  ['person1578590', 'schema:name', 'Jeff Rowe'],
#  ['movie614930', 'schema:actor', 'person2343267'],
#  ['person2343267', 'rdf:type', 'schema:Person'],
#  ['person2343267', 'schema:name', 'Micah Abbey'],
#  ['movie614930', 'schema:actor', 'person3127719'],
#  ['person3127719', 'rdf:type', 'schema:Person'],
#  ['person3127719', 'schema:name', 'Shamon Brown Jr.'],
#  ['movie614930', 'schema:actor', 'person1696351'],
#  ['person1696351', 'rdf:type', 'schema:Person'],
#  ['person1696351', 'schema:name', 'Nicolas Cantu'],
#  ['movie614930', 'schema:actor', 'person2239159'],
#  ['person2239159', 'rdf:type', 'schema:Person'],
#  ['person2239159', 'schema:name', 'Brady Noon'],
#  ['movie614930', 'schema:actor', 'person2195140'],
#  ['person2195140', 'rdf:type', 'schema:Person'],
#  ['person2195140', 'schema:name', 'Ayo Edebiri'],
#  ['movie614930', 'schema:actor', 'person52792'],
#  ['person52792', 'rdf:type', 'schema:Person'],
#  ['person52792', 'schema:name', 'Maya Rudolph'],
#  ['movie614930', 'schema:actor', 'person56446'],
#  ['person56446', 'rdf:type', 'schema:Person'],
#  ['person56446', 'schema:name', 'John Cena'],
#  ['movie614930', 'schema:actor', 'person19274'],
#  ['person19274', 'rdf:type', 'schema:Person'],
#  ['person19274', 'schema:name', 'Seth Rogen'],
#  ['movie614930', 'schema:actor', 'person9827'],
#  ['person9827', 'rdf:type', 'schema:Person'],
#  ['person9827', 'schema:name', 'Rose Byrne'],
#  ['movie614930', 'schema:actor', 'person1971031'],
#  ['person1971031', 'rdf:type', 'schema:Person'],
#  ['person1971031', 'schema:name', 'Natasia Demetriou'],
#  ['movie614930', 'ex:recommendedFrom', 'movie346698'],
#  ['movie617932', 'rdf:type', 'schema:Movie'],
#  ['movie617932', 'schema:name', 'Barbie'],
#  ['movie617932', 'schema:datePublished', 'published_1977'],
#  ['movie617932', 'schema:aggregateRating', 'avgVote_6.7'],
#  ['movie617932', 'schema:duration', 'runtime10'],
#  ['movie617932', 'ex:popularity', 'popul_0.0487'],
#  ['movie617932', 'ex:originalLanguage', 'en'],
#  ['movie617932', 'ex:originCountry', 'US'],
#  ['movie617932', 'schema:director', 'person2370012'],
#  ['person2370012', 'rdf:type', 'schema:Person'],
#  ['person2370012', 'schema:name', "Tina L'Hotsky"],
#  ['movie617932', 'schema:actor', 'person2370012'],
#  ['person2370012', 'rdf:type', 'schema:Person'],
#  ['person2370012', 'schema:name', "Tina L'Hotsky"],
#  ['movie617932', 'ex:recommendedFrom', 'movie346698'],
#  ['movie831438', 'rdf:type', 'schema:Movie'],
#  ['movie831438', 'schema:name', 'The Seed'],
#  ['movie831438', 'schema:datePublished', 'published_2021'],
#  ['movie831438', 'schema:aggregateRating', 'avgVote_4.9'],
#  ['movie831438', 'schema:duration', 'runtime91'],
#  ['movie831438', 'ex:popularity', 'popul_4.1076'],
#  ['movie831438', 'ex:originalLanguage', 'en'],
#  ['movie831438', 'ex:originCountry', 'GB'],
#  ['movie831438', 'schema:director', 'person3096424'],
#  ['person3096424', 'rdf:type', 'schema:Person'],
#  ['person3096424', 'schema:name', 'Sam Walker'],
#  ['movie831438', 'schema:actor', 'person96787'],
#  ['person96787', 'rdf:type', 'schema:Person'],
#  ['person96787', 'schema:name', 'Sophie Vavasseur'],
#  ['movie831438', 'schema:actor', 'person2487613'],
#  ['person2487613', 'rdf:type', 'schema:Person'],
#  ['person2487613', 'schema:name', 'Lucy Martin'],
#  ['movie831438', 'schema:actor', 'person1840067'],
#  ['person1840067', 'rdf:type', 'schema:Person'],
#  ['person1840067', 'schema:name', 'Chelsea Edge'],
#  ['movie831438', 'schema:actor', 'person1799544'],
#  ['person1799544', 'rdf:type', 'schema:Person'],
#  ['person1799544', 'schema:name', 'Anthony Edridge'],
#  ['movie831438', 'schema:actor', 'person3096422'],
#  ['person3096422', 'rdf:type', 'schema:Person'],
#  ['person3096422', 'schema:name', 'Shirley Barchou Pisani'],
#  ['movie831438', 'schema:actor', 'person3096423'],
#  ['person3096423', 'rdf:type', 'schema:Person'],
#  ['person3096423', 'schema:name', 'Jamie Wittebrood'],
#  ['movie831438', 'ex:recommendedFrom', 'movie961323'],
#  ...]

# %% [markdown]
# ## Append to KG (with backup)

# %%
# backup first
shutil.copy2(KG_PATH, BACKUP_PATH)

# append
new_df = pd.DataFrame(new_triples, columns=["head","rel","tail"])
assert len(new_df) > 0, "No new triples to append (all movies existed already?)."

with open(OUT_PATH, "a", encoding="utf-8") as f:
    new_df.to_csv(f, sep="\t", header=False, index=False)

print(f"Appended {len(new_df)} triples to", OUT_PATH)
print("Backup saved to", BACKUP_PATH)
# Out:
# Appended 28638 triples to ../data/kg/movie_kg_triples.tsv
# Backup saved to ../data/kg/movie_kg_triples_backup_20250914_213737.tsv
